# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
def get_device():
    if torch.cuda.is_available():
        device = 'cuda:0'
    else:
        device = 'cpu'
    return device

device = get_device()
print('Device: ',device)
# Out:
# Device:  cuda:0

# %%
# Paths
input_path = '/kaggle/input/2024-flame-ai-challenge/dataset/'

# Load data
train_df = pd.read_csv(os.path.join(input_path, 'train.csv'))
test_df = pd.read_csv(os.path.join(input_path, 'test.csv'))

# Function to load data
def load_dataX(idx, df, data_dir):
    csv_file = df.reset_index().to_dict(orient='list')
    dir_path = os.path.join(input_path, data_dir)
    
    id = csv_file['id'][idx]
    nt, Nx, Ny = csv_file['Nt'][idx], csv_file['Nx'][idx], csv_file['Ny'][idx]
    
    theta = np.fromfile(os.path.join(dir_path, csv_file['theta_filename'][idx]), dtype="<f4").reshape(nt, Nx, Ny)
    ustar = np.fromfile(os.path.join(dir_path, csv_file['ustar_filename'][idx]), dtype="<f4").reshape(nt, Nx, Ny)
    xi_f = np.fromfile(os.path.join(dir_path, csv_file['xi_filename'][idx]), dtype="<f4").reshape(nt, Nx, Ny)
    
    uin = csv_file['u'][idx]
    alpha = csv_file['alpha'][idx]

    return theta, ustar, xi_f, uin, alpha, id

# Function to extract fire positions
def extract_fire_positions(xi_f):
    return [np.argmax(np.mean(xi_f[t], axis=1)) for t in range(xi_f.shape[0])]

# Prepare training data
Datalist = []

for idx in range(len(train_df)):
    theta, ustar, xi_f, uin, alpha, id = load_dataX(idx, train_df, 'train')
    
    theta = torch.Tensor(theta).unsqueeze(1)
    ustar = torch.Tensor(ustar).unsqueeze(1)
    xi_f = torch.Tensor(xi_f).unsqueeze(1)
    
    uin_tensor = torch.zeros_like(xi_f) + uin
    alpha_tensor = torch.zeros_like(xi_f) + alpha
    
    TUXUA = torch.cat([theta,ustar,xi_f, uin_tensor, alpha_tensor], dim=1)
    TUXUA = TUXUA.unsqueeze(0)
    
    Datalist.append(TUXUA)
    
Data_train = torch.cat(Datalist)
print(Data_train.shape)

# Prepare testing data
Datalist = []

for idx in range(len(test_df)):
    theta, ustar, xi_f, uin, alpha, id = load_dataX(idx, test_df, 'test')
    
    theta = torch.Tensor(theta).unsqueeze(1)
    ustar = torch.Tensor(ustar).unsqueeze(1)
    xi_f = torch.Tensor(xi_f).unsqueeze(1)
    
    uin_tensor = torch.zeros_like(xi_f) + uin
    alpha_tensor = torch.zeros_like(xi_f) + alpha
    
    TUXUA = torch.cat([theta,ustar,xi_f, uin_tensor, alpha_tensor], dim=1)
    TUXUA = TUXUA.unsqueeze(0)
    
    Datalist.append(TUXUA)
    
Data_test = torch.cat(Datalist)
print(Data_test.shape)

D1 = Data_train.reshape([Data_train.shape[0]*Data_train.shape[1], Data_train.shape[2], Data_train.shape[3], Data_train.shape[4]])
D2 = Data_test.reshape([Data_test.shape[0]*Data_test.shape[1], Data_test.shape[2], Data_test.shape[3], Data_test.shape[4]])
print(D1.shape, D2.shape) 

D = torch.cat([D1,D2], dim=0)
MeanX = torch.mean(D, (0,2,3)).unsqueeze(0).unsqueeze(0).unsqueeze(-1).unsqueeze(-1).to(device)
StdX = torch.std(D, (0,2,3)).unsqueeze(0).unsqueeze(0).unsqueeze(-1).unsqueeze(-1).to(device)
print(StdX.shape)   # sample, timestep, channels [theta,ustar,xi_f, uin, alpha], X, Y
print(MeanX.shape)

MeanY = torch.mean(D, (0,2,3))[:3].unsqueeze(0).unsqueeze(0).unsqueeze(-1).unsqueeze(-1).to(device)
StdY = torch.std(D, (0,2,3))[:3].unsqueeze(0).unsqueeze(0).unsqueeze(-1).unsqueeze(-1).to(device)
print(StdY.shape)   # sample, timestep, channels [theta,ustar,xi_f], X, Y
print(MeanY.shape)
# Out:
# torch.Size([9, 150, 5, 113, 32])
# torch.Size([27, 5, 5, 113, 32])
# torch.Size([1350, 5, 113, 32]) torch.Size([135, 5, 113, 32])
# torch.Size([1, 1, 5, 1, 1])
# torch.Size([1, 1, 5, 1, 1])
# torch.Size([1, 1, 3, 1, 1])
# torch.Size([1, 1, 3, 1, 1])

# %%
# Create custom PyTorch dataset
class FlameDataset(Dataset):
    def __init__(self, Data, history = 1, prediction = 1):
        self.X = Data    #torch.Size([9, 150, 5, 113, 32])
        self.history = history
        self.prediction = prediction
        self.count_cases = Data.shape[0]
        self.count_timeIndices = Data.shape[1] - history - prediction + 1
        self.indices = torch.arange(self.count_cases*self.count_timeIndices)

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        case = idx%self.count_cases
        index = idx%self.count_timeIndices
        
        X = self.X[case,index:index + self.history,...]
        Y = self.X[case,index + self.history:index + self.history + self.prediction,:3,...]
        T = index + self.history #* torch.ones(idx.shape[0])
        return X, Y, T

# %%
class SpectralConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, modes1):
        super(SpectralConv1d, self).__init__()

        """
        1D Fourier layer. It does FFT, linear transform, and Inverse FFT.    
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1  #Number of Fourier modes to multiply, at most floor(N/2) + 1

        self.scale = (1 / (in_channels*out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, dtype=torch.cfloat))

    # Complex multiplication
    def compl_mul1d(self, input, weights):
        # (batch, in_channel, x ), (in_channel, out_channel, x) -> (batch, out_channel, x)
        return torch.einsum("bix,iox->box", input, weights)

    def forward(self, x):
        batchsize = x.shape[0]
        #Compute Fourier coeffcients up to factor of e^(- something constant)
        x_ft = torch.fft.rfft(x)

        # Multiply relevant Fourier modes 
        out_ft = torch.zeros(batchsize, self.out_channels,  x.size(-1)//2 + 1,  device=x.device, dtype=torch.cfloat)
        out_ft[:, :, :self.modes1] = self.compl_mul1d(x_ft[:, :, :self.modes1], self.weights1)

        #Return to physical space
        x = torch.fft.irfft(out_ft, n=x.size(-1))
        return x

class FNO1d(nn.Module):
    def __init__(self, num_channels, modes=16, width=64, initial_step=10):
        super(FNO1d, self).__init__()

        """
        The overall network. It contains 4 layers of the Fourier layer.
        1. Lift the input to the desire channel dimension by self.fc0 .
        2. 4 layers of the integral operators u' = (W + K)(u).
            W defined by self.w; K defined by self.conv .
        3. Project from the channel space to the output space by self.fc1 and self.fc2 .
        
        input: the solution of the initial condition and location (a(x), x)
        input shape: (batchsize, x=s, c=2)
        output: the solution of a later timestep
        output shape: (batchsize, x=s, c=1)
        """

        self.modes1 = modes
        self.width = width
        self.padding = 2 # pad the domain if input is non-periodic
        self.fc0 = nn.Linear(initial_step*num_channels+1, self.width) # input channel is 2: (a(x), x)

        self.conv0 = SpectralConv1d(self.width, self.width, self.modes1)
        self.conv1 = SpectralConv1d(self.width, self.width, self.modes1)
        self.conv2 = SpectralConv1d(self.width, self.width, self.modes1)
        self.conv3 = SpectralConv1d(self.width, self.width, self.modes1)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, num_channels)

    def forward(self, x):
        # x dim = [b, x1, t*v]
        #x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 2, 1)
        
        x = F.pad(x, [0, self.padding]) # pad the domain if input is non-periodic

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding]
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x.unsqueeze(-2)


class SpectralConv2d_fast(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super(SpectralConv2d_fast, self).__init__()

        """
        2D Fourier layer. It does FFT, linear transform, and Inverse FFT.    
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1 #Number of Fourier modes to multiply, at most floor(N/2) + 1
        self.modes2 = modes2

        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))

    # Complex multiplication
    def compl_mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        batchsize = x.shape[0]
        #Compute Fourier coeffcients up to factor of e^(- something constant)
        x_ft = torch.fft.rfft2(x)

        # Multiply relevant Fourier modes
        out_ft = torch.zeros(batchsize, self.out_channels,  x.size(-2), x.size(-1)//2 + 1, dtype=torch.cfloat, device=x.device)
        out_ft[:, :, :self.modes1, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, :self.modes1, :self.modes2], self.weights1)
        out_ft[:, :, -self.modes1:, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, -self.modes1:, :self.modes2], self.weights2)

        #Return to physical space
        x = torch.fft.irfft2(out_ft, s=(x.size(-2), x.size(-1)))
        return x

class FNO2d(nn.Module):
    def __init__(self, num_channels, modes1=12, modes2=12, width=20, initial_step=10, predict=1):
        super(FNO2d, self).__init__()

        """
        The overall network. It contains 4 layers of the Fourier layer.
        1. Lift the input to the desire channel dimension by self.fc0 .
        2. 4 layers of the integral operators u' = (W + K)(u).
            W defined by self.w; K defined by self.conv .
        3. Project from the channel space to the output space by self.fc1 and self.fc2 .
        
        input: the solution of the previous 10 timesteps + 2 locations (u(t-10, x, y), ..., u(t-1, x, y),  x, y)
        input shape: (batchsize, x, y, c)
        output: the solution of the next timestep
        output shape: (batchsize, x, y, c)
        """

        self.modes1 = modes1
        self.modes2 = modes2
        self.width = width
        self.padding = 2 # pad the domain if input is non-periodic
        self.fc0 = nn.Linear(initial_step*num_channels, self.width)
        # input channel is 12: the solution of the previous 10 timesteps + 2 locations (u(t-10, x, y), ..., u(t-1, x, y),  x, y)

        self.conv0 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d_fast(self.width, self.width, self.modes1, self.modes2)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, predict)

    def forward(self, x):
        # x dim = [b, x1, x2, t*v]   
        #x = torch.cat((x, grid), dim=-1)
        x = x.permute(0, 2, 3, 1)
        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)
        
        # Pad tensor with boundary condition
        x = F.pad(x, [0, self.padding, 0, self.padding])

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding] # Unpad the tensor
        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        x = x.permute(0, 3, 1, 2)
        return x
    

class SpectralConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2, modes3):
        super(SpectralConv3d, self).__init__()

        """
        3D Fourier layer. It does FFT, linear transform, and Inverse FFT.    
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1 #Number of Fourier modes to multiply, at most floor(N/2) + 1
        self.modes2 = modes2
        self.modes3 = modes3

        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, self.modes3, dtype=torch.cfloat))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, self.modes3, dtype=torch.cfloat))
        self.weights3 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, self.modes3, dtype=torch.cfloat))
        self.weights4 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, self.modes3, dtype=torch.cfloat))

    # Complex multiplication
    def compl_mul3d(self, input, weights):
        # (batch, in_channel, x,y,t ), (in_channel, out_channel, x,y,t) -> (batch, out_channel, x,y,t)
        return torch.einsum("bixyz,ioxyz->boxyz", input, weights)

    def forward(self, x):
        batchsize = x.shape[0]
        #Compute Fourier coeffcients up to factor of e^(- something constant)
        x_ft = torch.fft.rfftn(x, dim=[-3,-2,-1])

        # Multiply relevant Fourier modes
        out_ft = torch.zeros(batchsize, self.out_channels, x.size(-3), x.size(-2), x.size(-1)//2 + 1, dtype=torch.cfloat, device=x.device)
        out_ft[:, :, :self.modes1, :self.modes2, :self.modes3] = \
            self.compl_mul3d(x_ft[:, :, :self.modes1, :self.modes2, :self.modes3], self.weights1)
        out_ft[:, :, -self.modes1:, :self.modes2, :self.modes3] = \
            self.compl_mul3d(x_ft[:, :, -self.modes1:, :self.modes2, :self.modes3], self.weights2)
        out_ft[:, :, :self.modes1, -self.modes2:, :self.modes3] = \
            self.compl_mul3d(x_ft[:, :, :self.modes1, -self.modes2:, :self.modes3], self.weights3)
        out_ft[:, :, -self.modes1:, -self.modes2:, :self.modes3] = \
            self.compl_mul3d(x_ft[:, :, -self.modes1:, -self.modes2:, :self.modes3], self.weights4)

        #Return to physical space
        x = torch.fft.irfftn(out_ft, s=(x.size(-3), x.size(-2), x.size(-1)))
        return x

class FNO3d(nn.Module):
    def __init__(self, num_channels, modes1=8, modes2=8, modes3=8, width=20, initial_step=10):
        super(FNO3d, self).__init__()

        """
        The overall network. It contains 4 layers of the Fourier layer.
        1. Lift the input to the desire channel dimension by self.fc0 .
        2. 4 layers of the integral operators u' = (W + K)(u).
            W defined by self.w; K defined by self.conv .
        3. Project from the channel space to the output space by self.fc1 and self.fc2 .
        
        input: the solution of the first 10 timesteps + 3 locations (u(1, x, y), ..., u(10, x, y),  x, y, t). It's a constant function in time, except for the last index.
        input shape: (batchsize, x=64, y=64, t=40, c=13)
        output: the solution of the next 40 timesteps
        output shape: (batchsize, x=64, y=64, t=40, c=1)
        """

        self.modes1 = modes1
        self.modes2 = modes2
        self.modes3 = modes3
        self.width = width
        self.padding = 6 # pad the domain if input is non-periodic
        self.fc0 = nn.Linear(initial_step*num_channels+3, self.width)
        # input channel is 12: the solution of the first 10 timesteps + 3 locations (u(1, x, y), ..., u(10, x, y),  x, y, t)

        self.conv0 = SpectralConv3d(self.width, self.width, self.modes1, self.modes2, self.modes3)
        self.conv1 = SpectralConv3d(self.width, self.width, self.modes1, self.modes2, self.modes3)
        self.conv2 = SpectralConv3d(self.width, self.width, self.modes1, self.modes2, self.modes3)
        self.conv3 = SpectralConv3d(self.width, self.width, self.modes1, self.modes2, self.modes3)
        self.w0 = nn.Conv3d(self.width, self.width, 1)
        self.w1 = nn.Conv3d(self.width, self.width, 1)
        self.w2 = nn.Conv3d(self.width, self.width, 1)
        self.w3 = nn.Conv3d(self.width, self.width, 1)
        self.bn0 = torch.nn.BatchNorm3d(self.width)
        self.bn1 = torch.nn.BatchNorm3d(self.width)
        self.bn2 = torch.nn.BatchNorm3d(self.width)
        self.bn3 = torch.nn.BatchNorm3d(self.width)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, num_channels)

    def forward(self, x):
        # x dim = [b, x1, x2, x3, t*v]
        #x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 4, 1, 2, 3)
        
        x = F.pad(x, [0, self.padding]) # pad the domain if input is non-periodic

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding]
        x = x.permute(0, 2, 3, 4, 1) # pad the domain if input is non-periodic
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x.unsqueeze(-2)

# model = FNO2d(num_channels=1, modes1=16, modes2=16, width=42, initial_step=history, predict=prediction)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

def sinusoidal_embedding(n, d, device):
    # Returns the standard positional embedding
    embedding = torch.zeros(n, d).to(device)
    wk = torch.tensor([1 / 10_000 ** (2 * j / d) for j in range(d)]).to(device)
    wk = wk.reshape((1, d))
    t = torch.arange(n).reshape((n, 1)).to(device)
    embedding[:, ::2] = torch.sin(t * wk[:, ::2]).to(device)
    embedding[:, 1::2] = torch.cos(t * wk[:, ::2]).to(device)

    return embedding

class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
            #nn.LeakyReLU(1., inplace=True)    # to allow negative output
        )
        #self.fno_layer = FNO2d(num_channels=1, modes1=16, modes2=16, width=42, initial_step=out_channels, predict=out_channels)

    def forward(self, x):
        x = self.double_conv(x)
        #x = self.fno_layer(x)
        return x


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)
        #self.fno_layerUp = FNO2d(num_channels=1, modes1=16, modes2=16, width=42, initial_step=out_channels, predict=out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        #x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
        #                diffY // 2, diffY - diffY // 2])
        #breakpoint()
        # basically diffX diffY are placeholder without any value unless data is passed, so feature extractor fails
        #x1 = F.pad(x1, (int(str(diffX)) // 2, int(str(diffX)) - int(str(diffX)) // 2,
        #                int(str(diffY)) // 2, int(str(diffY)) - int(str(diffY)) // 2))     # get_graph_node_names was creating problem
        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        #
        # if you have padding issues, see
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        #x = self.fno_layerUp(x)
        return x


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)


class UNet(nn.Module):
    def __init__(self, n_filters = 4, n_channels=3, n_classes=1, bilinear=False, n_steps=1000, time_emb_dim=100, device = 'cpu'):
        super(UNet, self).__init__()
        self.n_channels = n_channels        
        self.n_classes = n_classes
        self.bilinear = bilinear
        self.device = device
        self.n_steps = n_steps

        # Sinusoidal embedding
#         self.time_embed = nn.Embedding(n_steps, time_emb_dim, device=device)
#         self.time_embed.weight.data = sinusoidal_embedding(n_steps, time_emb_dim, device)
#         self.time_embed.requires_grad_(False)
         
#         self.tei = self._make_te(time_emb_dim, n_channels)
#         self.inc = (DoubleConv(n_channels, n_filters))
        
#         self.te1 = self._make_te(time_emb_dim, n_filters)
#         self.down1 = (Down(n_filters, 2*n_filters))
        
#         self.te2 = self._make_te(time_emb_dim, 2*n_filters)
#         self.down2 = (Down(2*n_filters, 4*n_filters))
        
#         self.te3 = self._make_te(time_emb_dim, 4*n_filters)
#         self.down3 = (Down(4*n_filters, 8*n_filters))
        
#         factor = 2 if bilinear else 1
        
#         self.te4 = self._make_te(time_emb_dim, 8*n_filters)
#         self.down4 = (Down(8*n_filters, 16*n_filters // factor))
        
#         self.teu1i = self._make_te(time_emb_dim, 16*n_filters)       
#         self.teu1j = self._make_te(time_emb_dim, 8*n_filters)       
#         self.up1 = (Up(16*n_filters, 8*n_filters // factor, bilinear))
        
#         self.teu2i = self._make_te(time_emb_dim, 8*n_filters)
#         self.teu2j = self._make_te(time_emb_dim, 4*n_filters)       
#         self.up2 = (Up(8*n_filters, 4*n_filters // factor, bilinear))
        
#         self.teu3i = self._make_te(time_emb_dim, 4*n_filters)
#         self.teu3j = self._make_te(time_emb_dim, 2*n_filters)       
#         self.up3 = (Up(4*n_filters, 2*n_filters // factor, bilinear))
        
#         self.teu4i = self._make_te(time_emb_dim, 2*n_filters)
#         self.teu4j = self._make_te(time_emb_dim, n_filters)       
#         self.up4 = (Up(2*n_filters, n_filters, bilinear))
        
#         self.teo = self._make_te(time_emb_dim, n_filters)
#         self.outc = (OutConv(n_filters, n_classes)) # DoubleConv(n_fliters,n_classes)  # (OutConv(64, n_classes))    #1x1 conv can allow negative values in output to be mapped
        self.fno_layer_1st = FNO2d(num_channels=1, modes1=16, modes2=16, width=96, initial_step=n_channels, predict=8)
        self.fno_layer_inner = FNO2d(num_channels=1, modes1=16, modes2=16, width=96, initial_step=8, predict=8)
        self.fno_layer_last = FNO2d(num_channels=1, modes1=16, modes2=16, width=96, initial_step=8, predict=n_classes)
        
        
    def forward(self, x, t):
        
        Xshape = x.shape
        x = (x - MeanX)/StdX
        
        x = x.reshape([Xshape[0], Xshape[1] * Xshape[2], Xshape[3], Xshape[4]])
        
        #x_ = x
        
#         #t = self.time_embed(t.long())  # takes in long or int tensor not float
#         n = len(x)
        
#         x1 = self.inc(x + self.tei(t).reshape(n, -1, 1, 1))
#         x2 = self.down1(x1 + self.te1(t).reshape(n, -1, 1, 1))
#         x3 = self.down2(x2 + self.te2(t).reshape(n, -1, 1, 1))
#         x4 = self.down3(x3 + self.te3(t).reshape(n, -1, 1, 1))
#         x5 = self.down4(x4 + self.te4(t).reshape(n, -1, 1, 1))
#         x = self.up1(x5 + self.teu1i(t).reshape(n, -1, 1, 1), x4 + self.teu1j(t).reshape(n, -1, 1, 1))
#         x = self.up2(x + self.teu2i(t).reshape(n, -1, 1, 1), x3 + self.teu2j(t).reshape(n, -1, 1, 1))
#         x = self.up3(x + self.teu3i(t).reshape(n, -1, 1, 1), x2 + self.teu3j(t).reshape(n, -1, 1, 1))
#         x = self.up4(x + self.teu4i(t).reshape(n, -1, 1, 1), x1 + self.teu4j(t).reshape(n, -1, 1, 1))
#         x = self.outc(x + self.teo(t).reshape(n, -1, 1, 1))
        
        x = self.fno_layer_1st(x)
        for i in range(5):
            x = self.fno_layer_inner(x) + x
        x = self.fno_layer_last(x)
        
        x = x.reshape([Xshape[0], 1, 3, Xshape[3], Xshape[4]])
        
        x = (x * StdY) + MeanY
        
#         #x = 0.01*x + x_[:,-1:,:3,:,:]
#         x[:,:,2:,:,:][x[:,:,2:,:,:]>=0.25] = 1.        
        x[:,:,2:,:,:][x[:,:,2:,:,:]<0.02] = 0.        
        
        #print(x.shape)  32,T,3,113,32
        
        return x
        # logits = self.outc(x)
        # return logits
        
    def _make_te(self, dim_in, dim_out):
        return nn.Sequential(
            nn.Linear(dim_in, dim_out), nn.SiLU(), nn.Linear(dim_out, dim_out)
        )

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# Model parameters
batch_size = 32
learning_rate = 1e-3
num_epochs = 100
num_filters = 64
history = 4
prediction = 1

# Create dataset and dataloaders for training and test sets
train_dataset = FlameDataset(Data_train, history = history, prediction = prediction)
test_dataset = FlameDataset(Data_test, history = history, prediction = prediction)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Initialize the model, loss function, and optimizer
model = UNet(n_filters = num_filters, n_channels = 5 * history, n_classes = 3 * prediction, n_steps=15, time_emb_dim=10, device=device).to(device)
best_model = UNet(n_filters = num_filters, n_channels = 5 * history, n_classes = 3 * prediction, n_steps=15, time_emb_dim=10, device=device).to(device)
print('Number of model parameters = %3d'%(count_parameters(model)))

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# Number of model parameters = 56778291

# %%
#model = torch.load("model.pth")

# %%
# Train the model
train_loss = []
validation_loss = []
best_loss = 10000
best_epoch = 0
for epoch in range(num_epochs):
    running_loss = 0.0
    running_val_loss = 0.0
    for xx,yy,tt  in train_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        optimizer.zero_grad()
        outputs = model(xx, tt*0.)
        
        theta_misfit = criterion(outputs[:,:,0:1,:,:], yy[:,:,0:1,:,:])/criterion(outputs[:,:,0:1,:,:]*0., yy[:,:,0:1,:,:])  
        ustar_misfit = criterion(outputs[:,:,1:2,:,:], yy[:,:,1:2,:,:])/criterion(outputs[:,:,1:2,:,:]*0., yy[:,:,1:2,:,:]) 
        xi_f_misfit = criterion(outputs[:,:,2:3,:,:], yy[:,:,2:3,:,:])/criterion(outputs[:,:,2:3,:,:]*0., yy[:,:,2:3,:,:])
        
        loss = theta_misfit + ustar_misfit + xi_f_misfit
        
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
#     for xx,yy,tt  in test_loader:
#         xx = xx.to(device)
#         yy = yy.to(device)
#         tt = tt.to(device)
#         optimizer.zero_grad()
#         outputs = model(xx, tt*0.)
        
#         theta_misfit = criterion(outputs[:,:,0:1,:,:], yy[:,:,0:1,:,:])/criterion(outputs[:,:,0:1,:,:]*0., yy[:,:,0:1,:,:])  
#         ustar_misfit = criterion(outputs[:,:,1:2,:,:], yy[:,:,1:2,:,:])/criterion(outputs[:,:,1:2,:,:]*0., yy[:,:,1:2,:,:]) 
#         xi_f_misfit = criterion(outputs[:,:,2:3,:,:], yy[:,:,2:3,:,:])/criterion(outputs[:,:,2:3,:,:]*0., yy[:,:,2:3,:,:])
        
#         loss = theta_misfit + ustar_misfit + xi_f_misfit
        
#         loss.backward()
#         optimizer.step()
    
    for xx,yy,tt  in test_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        with torch.no_grad():
            outputs = model(xx, tt*0.)
        
            val_loss = criterion(outputs, yy)
        running_val_loss += val_loss.item()
    
    trn_loss = running_loss/len(train_loader)
    val_loss = running_val_loss/len(test_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {trn_loss:.3e}, Validation Loss: {val_loss:.3e}")
    
    train_loss.append(trn_loss)
    validation_loss.append(val_loss)
    
    if val_loss <= best_loss:
        best_model.load_state_dict(model.state_dict())
        torch.save(best_model, 'best_model.pth')
        best_epoch = epoch
        best_loss = val_loss
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 14
#      12 tt = tt.to(device)
#      13 optimizer.zero_grad()
# ---> 14 outputs = model(xx, tt*0.)
#      16 theta_misfit = criterion(outputs[:,:,0:1,:,:], yy[:,:,0:1,:,:])/criterion(outputs[:,:,0:1,:,:]*0., yy[:,:,0:1,:,:])
#      17 ustar_misfit = criterion(outputs[:,:,1:2,:,:], yy[:,:,1:2,:,:])/criterion(outputs[:,:,1:2,:,:]*0., yy[:,:,1:2,:,:])
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[11], line 179, in UNet.forward(self, x, t)
#     161         x = x.reshape([Xshape[0], Xshape[1] * Xshape[2], Xshape[3], Xshape[4]])
#     163         #x_ = x
#     164
#     165 #         #t = self.time_embed(t.long())  # takes in long or int tensor not float
#    (...)
#     176 #         x = self.up4(x + self.teu4i(t).reshape(n, -1, 1, 1), x1 + self.teu4j(t).reshape(n, -1, 1, 1))
#     177 #         x = self.outc(x + self.teo(t).reshape(n, -1, 1, 1))
# --> 179         x = self.fno_layer_1st(x) + x
#     180         for i in range(5):
#     181             x = self.fno_layer_inner(x) + x
#
# RuntimeError: The size of tensor a (8) must match the size of tensor b (20) at non-singleton dimension 1

# %%
torch.save(model, 'model.pth')
print('best epoch: ', best_epoch + 1)

plt.plot(train_loss, label="Train Loss")
plt.plot(validation_loss, label="Validation Loss")
plt.legend()
plt.yscale("log")
plt.title("Loss Curve")
plt.show()
# Out:
# best epoch:  91

# %%
# Train the model AGAIN
learning_rate = 1e-4
num_epochs = 500
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    running_loss = 0.0
    running_val_loss = 0.0
    for xx,yy,tt  in train_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        optimizer.zero_grad()
        outputs = model(xx, tt*0.)
        
        theta_misfit = criterion(outputs[:,:,0:1,:,:], yy[:,:,0:1,:,:])/criterion(outputs[:,:,0:1,:,:]*0., yy[:,:,0:1,:,:])  
        ustar_misfit = criterion(outputs[:,:,1:2,:,:], yy[:,:,1:2,:,:])/criterion(outputs[:,:,1:2,:,:]*0., yy[:,:,1:2,:,:]) 
        xi_f_misfit = criterion(outputs[:,:,2:3,:,:], yy[:,:,2:3,:,:])/criterion(outputs[:,:,2:3,:,:]*0., yy[:,:,2:3,:,:])
        
        loss = theta_misfit + ustar_misfit + xi_f_misfit
        
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    for xx,yy,tt  in test_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        optimizer.zero_grad()
        outputs = model(xx, tt*0.)
        
        theta_misfit = criterion(outputs[:,:,0:1,:,:], yy[:,:,0:1,:,:])/criterion(outputs[:,:,0:1,:,:]*0., yy[:,:,0:1,:,:])  
        ustar_misfit = criterion(outputs[:,:,1:2,:,:], yy[:,:,1:2,:,:])/criterion(outputs[:,:,1:2,:,:]*0., yy[:,:,1:2,:,:]) 
        xi_f_misfit = criterion(outputs[:,:,2:3,:,:], yy[:,:,2:3,:,:])/criterion(outputs[:,:,2:3,:,:]*0., yy[:,:,2:3,:,:])
        
        loss = theta_misfit + ustar_misfit + xi_f_misfit
        
        loss.backward()
        optimizer.step()
    
    for xx,yy,tt  in test_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        with torch.no_grad():
            outputs = model(xx, tt*0.)
        
            val_loss = criterion(outputs, yy)
        running_val_loss += val_loss.item()
    
    trn_loss = running_loss/len(train_loader)
    val_loss = running_val_loss/len(test_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {trn_loss:.3e}, Validation Loss: {val_loss:.3e}")
    
    train_loss.append(trn_loss)
    validation_loss.append(val_loss)
    
    if val_loss <= best_loss:
        best_model.load_state_dict(model.state_dict())
        torch.save(best_model, 'best_model.pth')
        best_epoch = epoch
        best_loss = val_loss
# Out:
# Epoch [1/500], Train Loss: 2.495e-02, Validation Loss: 6.531e+01
# Epoch [2/500], Train Loss: 2.258e-02, Validation Loss: 6.497e+01
# Epoch [3/500], Train Loss: 2.100e-02, Validation Loss: 6.424e+01
# Epoch [4/500], Train Loss: 2.278e-02, Validation Loss: 6.363e+01
# Epoch [5/500], Train Loss: 2.045e-02, Validation Loss: 6.301e+01
# Epoch [6/500], Train Loss: 1.989e-02, Validation Loss: 6.163e+01
# Epoch [7/500], Train Loss: 1.948e-02, Validation Loss: 6.103e+01
# Epoch [8/500], Train Loss: 1.941e-02, Validation Loss: 5.976e+01
# Epoch [9/500], Train Loss: 1.916e-02, Validation Loss: 5.872e+01
# Epoch [10/500], Train Loss: 1.894e-02, Validation Loss: 5.769e+01
# Epoch [11/500], Train Loss: 1.890e-02, Validation Loss: 5.722e+01
# Epoch [12/500], Train Loss: 1.887e-02, Validation Loss: 5.632e+01
# Epoch [13/500], Train Loss: 1.882e-02, Validation Loss: 5.537e+01
# Epoch [14/500], Train Loss: 1.958e-02, Validation Loss: 5.479e+01
# Epoch [15/500], Train Loss: 1.851e-02, Validation Loss: 5.387e+01
# Epoch [16/500], Train Loss: 1.820e-02, Validation Loss: 5.337e+01
# Epoch [17/500], Train Loss: 1.914e-02, Validation Loss: 5.243e+01
# Epoch [18/500], Train Loss: 1.819e-02, Validation Loss: 5.185e+01
# Epoch [19/500], Train Loss: 1.813e-02, Validation Loss: 5.099e+01
# Epoch [20/500], Train Loss: 1.778e-02, Validation Loss: 5.038e+01
# Epoch [21/500], Train Loss: 1.786e-02, Validation Loss: 4.990e+01
# Epoch [22/500], Train Loss: 1.790e-02, Validation Loss: 4.918e+01
# Epoch [23/500], Train Loss: 1.772e-02, Validation Loss: 4.868e+01
# Epoch [24/500], Train Loss: 1.756e-02, Validation Loss: 4.817e+01
# Epoch [25/500], Train Loss: 1.753e-02, Validation Loss: 4.775e+01
# Epoch [26/500], Train Loss: 1.748e-02, Validation Loss: 4.699e+01
# Epoch [27/500], Train Loss: 1.748e-02, Validation Loss: 4.666e+01
# Epoch [28/500], Train Loss: 1.743e-02, Validation Loss: 4.615e+01
# Epoch [29/500], Train Loss: 1.735e-02, Validation Loss: 4.575e+01
# Epoch [30/500], Train Loss: 1.728e-02, Validation Loss: 4.527e+01
# Epoch [31/500], Train Loss: 1.736e-02, Validation Loss: 4.470e+01
# Epoch [32/500], Train Loss: 1.715e-02, Validation Loss: 4.431e+01
# Epoch [33/500], Train Loss: 1.714e-02, Validation Loss: 4.394e+01
# Epoch [34/500], Train Loss: 1.685e-02, Validation Loss: 4.339e+01
# Epoch [35/500], Train Loss: 1.718e-02, Validation Loss: 4.308e+01
# Epoch [36/500], Train Loss: 1.725e-02, Validation Loss: 4.275e+01
# Epoch [37/500], Train Loss: 1.727e-02, Validation Loss: 4.217e+01
# Epoch [38/500], Train Loss: 1.675e-02, Validation Loss: 4.184e+01
# Epoch [39/500], Train Loss: 1.672e-02, Validation Loss: 4.158e+01
# Epoch [40/500], Train Loss: 1.685e-02, Validation Loss: 4.110e+01
# Epoch [41/500], Train Loss: 1.673e-02, Validation Loss: 4.084e+01
# Epoch [42/500], Train Loss: 1.688e-02, Validation Loss: 4.046e+01
# Epoch [43/500], Train Loss: 1.664e-02, Validation Loss: 4.015e+01
# Epoch [44/500], Train Loss: 1.644e-02, Validation Loss: 3.969e+01
# Epoch [45/500], Train Loss: 1.642e-02, Validation Loss: 3.940e+01
# Epoch [46/500], Train Loss: 1.626e-02, Validation Loss: 3.902e+01
# Epoch [47/500], Train Loss: 1.646e-02, Validation Loss: 3.859e+01
# Epoch [48/500], Train Loss: 1.644e-02, Validation Loss: 3.841e+01
# Epoch [49/500], Train Loss: 1.628e-02, Validation Loss: 3.796e+01
# Epoch [50/500], Train Loss: 1.649e-02, Validation Loss: 3.756e+01
# Epoch [51/500], Train Loss: 1.656e-02, Validation Loss: 3.728e+01
# Epoch [52/500], Train Loss: 1.623e-02, Validation Loss: 3.682e+01
# Epoch [53/500], Train Loss: 1.668e-02, Validation Loss: 3.668e+01
# Epoch [54/500], Train Loss: 1.658e-02, Validation Loss: 3.695e+01
# Epoch [55/500], Train Loss: 1.711e-02, Validation Loss: 3.722e+01
# Epoch [56/500], Train Loss: 1.676e-02, Validation Loss: 3.728e+01
# Epoch [57/500], Train Loss: 1.608e-02, Validation Loss: 3.636e+01
# Epoch [58/500], Train Loss: 1.597e-02, Validation Loss: 3.678e+01
# Epoch [59/500], Train Loss: 1.600e-02, Validation Loss: 3.628e+01
# Epoch [60/500], Train Loss: 1.579e-02, Validation Loss: 3.576e+01
# Epoch [61/500], Train Loss: 1.618e-02, Validation Loss: 3.514e+01
# Epoch [62/500], Train Loss: 1.576e-02, Validation Loss: 3.488e+01
# Epoch [63/500], Train Loss: 1.575e-02, Validation Loss: 3.439e+01
# Epoch [64/500], Train Loss: 1.619e-02, Validation Loss: 3.412e+01
# Epoch [65/500], Train Loss: 1.550e-02, Validation Loss: 3.387e+01
# Epoch [66/500], Train Loss: 1.546e-02, Validation Loss: 3.360e+01
# Epoch [67/500], Train Loss: 1.581e-02, Validation Loss: 3.329e+01
# Epoch [68/500], Train Loss: 1.546e-02, Validation Loss: 3.310e+01
# Epoch [69/500], Train Loss: 1.555e-02, Validation Loss: 3.281e+01
# Epoch [70/500], Train Loss: 1.601e-02, Validation Loss: 3.257e+01
# Epoch [71/500], Train Loss: 1.553e-02, Validation Loss: 3.237e+01
# Epoch [72/500], Train Loss: 1.548e-02, Validation Loss: 3.209e+01
# Epoch [73/500], Train Loss: 1.563e-02, Validation Loss: 3.189e+01
# Epoch [74/500], Train Loss: 1.591e-02, Validation Loss: 3.169e+01
# Epoch [75/500], Train Loss: 1.552e-02, Validation Loss: 3.147e+01
# Epoch [76/500], Train Loss: 1.543e-02, Validation Loss: 3.121e+01
# Epoch [77/500], Train Loss: 1.529e-02, Validation Loss: 3.100e+01
# Epoch [78/500], Train Loss: 1.537e-02, Validation Loss: 3.091e+01
# Epoch [79/500], Train Loss: 1.530e-02, Validation Loss: 3.061e+01
# Epoch [80/500], Train Loss: 1.533e-02, Validation Loss: 3.044e+01
# Epoch [81/500], Train Loss: 1.543e-02, Validation Loss: 3.026e+01
# Epoch [82/500], Train Loss: 1.516e-02, Validation Loss: 3.012e+01
# Epoch [83/500], Train Loss: 1.561e-02, Validation Loss: 2.981e+01
# Epoch [84/500], Train Loss: 1.516e-02, Validation Loss: 2.953e+01
# Epoch [85/500], Train Loss: 1.506e-02, Validation Loss: 2.932e+01
# Epoch [86/500], Train Loss: 1.530e-02, Validation Loss: 2.920e+01
# Epoch [87/500], Train Loss: 1.510e-02, Validation Loss: 2.893e+01
# Epoch [88/500], Train Loss: 1.545e-02, Validation Loss: 2.876e+01
# Epoch [89/500], Train Loss: 1.506e-02, Validation Loss: 2.854e+01
# Epoch [90/500], Train Loss: 1.494e-02, Validation Loss: 2.836e+01
# Epoch [91/500], Train Loss: 1.508e-02, Validation Loss: 2.818e+01
# Epoch [92/500], Train Loss: 1.576e-02, Validation Loss: 2.795e+01
# Epoch [93/500], Train Loss: 1.496e-02, Validation Loss: 2.779e+01
# Epoch [94/500], Train Loss: 1.516e-02, Validation Loss: 2.770e+01
# Epoch [95/500], Train Loss: 1.491e-02, Validation Loss: 2.743e+01
# Epoch [96/500], Train Loss: 1.493e-02, Validation Loss: 2.732e+01
# Epoch [97/500], Train Loss: 1.488e-02, Validation Loss: 2.708e+01
# Epoch [98/500], Train Loss: 1.486e-02, Validation Loss: 2.693e+01
# Epoch [99/500], Train Loss: 1.514e-02, Validation Loss: 2.675e+01
# Epoch [100/500], Train Loss: 1.482e-02, Validation Loss: 2.658e+01
# Epoch [101/500], Train Loss: 1.486e-02, Validation Loss: 2.636e+01
# Epoch [102/500], Train Loss: 1.480e-02, Validation Loss: 2.621e+01
# Epoch [103/500], Train Loss: 1.486e-02, Validation Loss: 2.600e+01
# Epoch [104/500], Train Loss: 1.473e-02, Validation Loss: 2.586e+01
# Epoch [105/500], Train Loss: 1.488e-02, Validation Loss: 2.598e+01
# Epoch [106/500], Train Loss: 1.482e-02, Validation Loss: 2.585e+01
# Epoch [107/500], Train Loss: 1.459e-02, Validation Loss: 2.563e+01
# Epoch [108/500], Train Loss: 1.489e-02, Validation Loss: 2.546e+01
# Epoch [109/500], Train Loss: 1.492e-02, Validation Loss: 2.536e+01
# Epoch [110/500], Train Loss: 1.470e-02, Validation Loss: 2.517e+01
# Epoch [111/500], Train Loss: 1.444e-02, Validation Loss: 2.508e+01
# Epoch [112/500], Train Loss: 1.458e-02, Validation Loss: 2.482e+01
# Epoch [113/500], Train Loss: 1.475e-02, Validation Loss: 2.487e+01
# Epoch [114/500], Train Loss: 1.447e-02, Validation Loss: 2.455e+01
# Epoch [115/500], Train Loss: 1.450e-02, Validation Loss: 2.441e+01
# Epoch [116/500], Train Loss: 1.440e-02, Validation Loss: 2.424e+01
# Epoch [117/500], Train Loss: 1.442e-02, Validation Loss: 2.415e+01
# Epoch [118/500], Train Loss: 1.451e-02, Validation Loss: 2.397e+01
# Epoch [119/500], Train Loss: 1.422e-02, Validation Loss: 2.387e+01
# Epoch [120/500], Train Loss: 1.436e-02, Validation Loss: 2.376e+01
# Epoch [121/500], Train Loss: 1.414e-02, Validation Loss: 2.360e+01
# Epoch [122/500], Train Loss: 1.419e-02, Validation Loss: 2.343e+01
# Epoch [123/500], Train Loss: 1.415e-02, Validation Loss: 2.327e+01
# Epoch [124/500], Train Loss: 1.411e-02, Validation Loss: 2.312e+01
# Epoch [125/500], Train Loss: 1.467e-02, Validation Loss: 2.309e+01
# Epoch [126/500], Train Loss: 1.419e-02, Validation Loss: 2.323e+01
# Epoch [127/500], Train Loss: 1.469e-02, Validation Loss: 2.292e+01
# Epoch [128/500], Train Loss: 1.560e-02, Validation Loss: 2.272e+01
# Epoch [129/500], Train Loss: 1.433e-02, Validation Loss: 2.254e+01
# Epoch [130/500], Train Loss: 1.412e-02, Validation Loss: 2.239e+01
# Epoch [131/500], Train Loss: 1.420e-02, Validation Loss: 2.225e+01
# Epoch [132/500], Train Loss: 1.405e-02, Validation Loss: 2.208e+01
# Epoch [133/500], Train Loss: 1.450e-02, Validation Loss: 2.197e+01
# Epoch [134/500], Train Loss: 1.486e-02, Validation Loss: 2.182e+01
# Epoch [135/500], Train Loss: 1.399e-02, Validation Loss: 2.202e+01
# Epoch [136/500], Train Loss: 1.421e-02, Validation Loss: 2.187e+01
# Epoch [137/500], Train Loss: 1.430e-02, Validation Loss: 2.198e+01
# Epoch [138/500], Train Loss: 1.440e-02, Validation Loss: 2.166e+01
# Epoch [139/500], Train Loss: 1.434e-02, Validation Loss: 2.148e+01
# Epoch [140/500], Train Loss: 1.397e-02, Validation Loss: 2.130e+01
# Epoch [141/500], Train Loss: 1.444e-02, Validation Loss: 2.126e+01
# Epoch [142/500], Train Loss: 1.394e-02, Validation Loss: 2.111e+01
# Epoch [143/500], Train Loss: 1.397e-02, Validation Loss: 2.107e+01
# Epoch [144/500], Train Loss: 1.396e-02, Validation Loss: 2.093e+01
# Epoch [145/500], Train Loss: 1.391e-02, Validation Loss: 2.121e+01
# Epoch [146/500], Train Loss: 1.383e-02, Validation Loss: 2.136e+01
# Epoch [147/500], Train Loss: 1.444e-02, Validation Loss: 2.114e+01
# Epoch [148/500], Train Loss: 1.375e-02, Validation Loss: 2.104e+01
# Epoch [149/500], Train Loss: 1.403e-02, Validation Loss: 2.080e+01
# Epoch [150/500], Train Loss: 1.383e-02, Validation Loss: 2.057e+01
# Epoch [151/500], Train Loss: 1.401e-02, Validation Loss: 2.037e+01
# Epoch [152/500], Train Loss: 1.378e-02, Validation Loss: 2.025e+01
# Epoch [153/500], Train Loss: 1.444e-02, Validation Loss: 2.011e+01
# Epoch [154/500], Train Loss: 1.382e-02, Validation Loss: 1.999e+01
# Epoch [155/500], Train Loss: 1.382e-02, Validation Loss: 1.984e+01
# Epoch [156/500], Train Loss: 1.388e-02, Validation Loss: 1.971e+01
# Epoch [157/500], Train Loss: 1.418e-02, Validation Loss: 1.961e+01
# Epoch [158/500], Train Loss: 1.348e-02, Validation Loss: 1.949e+01
# Epoch [159/500], Train Loss: 1.392e-02, Validation Loss: 1.937e+01
# Epoch [160/500], Train Loss: 1.406e-02, Validation Loss: 1.924e+01
# Epoch [161/500], Train Loss: 1.343e-02, Validation Loss: 1.911e+01
# Epoch [162/500], Train Loss: 1.357e-02, Validation Loss: 1.901e+01
# Epoch [163/500], Train Loss: 1.396e-02, Validation Loss: 1.893e+01
# Epoch [164/500], Train Loss: 1.399e-02, Validation Loss: 1.879e+01
# Epoch [165/500], Train Loss: 1.366e-02, Validation Loss: 1.872e+01
# Epoch [166/500], Train Loss: 1.369e-02, Validation Loss: 1.866e+01
# Epoch [167/500], Train Loss: 1.354e-02, Validation Loss: 1.852e+01
# Epoch [168/500], Train Loss: 1.351e-02, Validation Loss: 1.842e+01
# Epoch [169/500], Train Loss: 1.387e-02, Validation Loss: 1.832e+01
# Epoch [170/500], Train Loss: 1.340e-02, Validation Loss: 1.819e+01
# Epoch [171/500], Train Loss: 1.355e-02, Validation Loss: 1.812e+01
# Epoch [172/500], Train Loss: 1.361e-02, Validation Loss: 1.806e+01
# Epoch [173/500], Train Loss: 1.344e-02, Validation Loss: 1.801e+01
# Epoch [174/500], Train Loss: 1.372e-02, Validation Loss: 1.809e+01
# Epoch [175/500], Train Loss: 1.358e-02, Validation Loss: 1.808e+01
# Epoch [176/500], Train Loss: 1.359e-02, Validation Loss: 1.795e+01
# Epoch [177/500], Train Loss: 1.348e-02, Validation Loss: 1.802e+01
# Epoch [178/500], Train Loss: 1.352e-02, Validation Loss: 1.799e+01
# Epoch [179/500], Train Loss: 1.393e-02, Validation Loss: 1.804e+01
# Epoch [180/500], Train Loss: 1.396e-02, Validation Loss: 1.835e+01
# Epoch [181/500], Train Loss: 1.370e-02, Validation Loss: 1.804e+01
# Epoch [182/500], Train Loss: 1.372e-02, Validation Loss: 1.784e+01
# Epoch [183/500], Train Loss: 1.359e-02, Validation Loss: 1.776e+01
# Epoch [184/500], Train Loss: 1.334e-02, Validation Loss: 1.773e+01
# Epoch [185/500], Train Loss: 1.332e-02, Validation Loss: 1.762e+01
# Epoch [186/500], Train Loss: 1.347e-02, Validation Loss: 1.765e+01
# Epoch [187/500], Train Loss: 1.352e-02, Validation Loss: 1.746e+01
# Epoch [188/500], Train Loss: 1.344e-02, Validation Loss: 1.732e+01
# Epoch [189/500], Train Loss: 1.360e-02, Validation Loss: 1.720e+01
# Epoch [190/500], Train Loss: 1.315e-02, Validation Loss: 1.711e+01
# Epoch [191/500], Train Loss: 1.458e-02, Validation Loss: 1.702e+01
# Epoch [192/500], Train Loss: 1.354e-02, Validation Loss: 1.692e+01
# Epoch [193/500], Train Loss: 1.306e-02, Validation Loss: 1.686e+01
# Epoch [194/500], Train Loss: 1.330e-02, Validation Loss: 1.678e+01
# Epoch [195/500], Train Loss: 1.352e-02, Validation Loss: 1.671e+01
# Epoch [196/500], Train Loss: 1.326e-02, Validation Loss: 1.664e+01
# Epoch [197/500], Train Loss: 1.336e-02, Validation Loss: 1.657e+01
# Epoch [198/500], Train Loss: 1.316e-02, Validation Loss: 1.649e+01
# Epoch [199/500], Train Loss: 1.310e-02, Validation Loss: 1.643e+01
# Epoch [200/500], Train Loss: 1.332e-02, Validation Loss: 1.635e+01
# Epoch [201/500], Train Loss: 1.294e-02, Validation Loss: 1.627e+01
# Epoch [202/500], Train Loss: 1.338e-02, Validation Loss: 1.623e+01
# Epoch [203/500], Train Loss: 1.290e-02, Validation Loss: 1.615e+01
# Epoch [204/500], Train Loss: 1.332e-02, Validation Loss: 1.609e+01
# Epoch [205/500], Train Loss: 1.335e-02, Validation Loss: 1.602e+01
# Epoch [206/500], Train Loss: 1.299e-02, Validation Loss: 1.595e+01
# Epoch [207/500], Train Loss: 1.315e-02, Validation Loss: 1.587e+01
# Epoch [208/500], Train Loss: 1.361e-02, Validation Loss: 1.580e+01
# Epoch [209/500], Train Loss: 1.286e-02, Validation Loss: 1.580e+01
# Epoch [210/500], Train Loss: 1.316e-02, Validation Loss: 1.568e+01
# Epoch [211/500], Train Loss: 1.281e-02, Validation Loss: 1.560e+01
# Epoch [212/500], Train Loss: 1.280e-02, Validation Loss: 1.557e+01
# Epoch [213/500], Train Loss: 1.306e-02, Validation Loss: 1.556e+01
# Epoch [214/500], Train Loss: 1.316e-02, Validation Loss: 1.550e+01
# Epoch [215/500], Train Loss: 1.291e-02, Validation Loss: 1.564e+01
# Epoch [216/500], Train Loss: 1.317e-02, Validation Loss: 1.535e+01
# Epoch [217/500], Train Loss: 1.323e-02, Validation Loss: 1.535e+01
# Epoch [218/500], Train Loss: 1.299e-02, Validation Loss: 1.524e+01
# Epoch [219/500], Train Loss: 1.276e-02, Validation Loss: 1.534e+01
# Epoch [220/500], Train Loss: 1.310e-02, Validation Loss: 1.509e+01
# Epoch [221/500], Train Loss: 1.277e-02, Validation Loss: 1.509e+01
# Epoch [222/500], Train Loss: 1.303e-02, Validation Loss: 1.497e+01
# Epoch [223/500], Train Loss: 1.321e-02, Validation Loss: 1.500e+01
# Epoch [224/500], Train Loss: 1.451e-02, Validation Loss: 1.485e+01
# Epoch [225/500], Train Loss: 1.268e-02, Validation Loss: 1.508e+01
# Epoch [226/500], Train Loss: 1.269e-02, Validation Loss: 1.480e+01
# Epoch [227/500], Train Loss: 1.317e-02, Validation Loss: 1.509e+01
# Epoch [228/500], Train Loss: 1.261e-02, Validation Loss: 1.473e+01
# Epoch [229/500], Train Loss: 1.286e-02, Validation Loss: 1.480e+01
# Epoch [230/500], Train Loss: 1.266e-02, Validation Loss: 1.465e+01
# Epoch [231/500], Train Loss: 1.286e-02, Validation Loss: 1.486e+01
# Epoch [232/500], Train Loss: 1.264e-02, Validation Loss: 1.454e+01
# Epoch [233/500], Train Loss: 1.280e-02, Validation Loss: 1.435e+01
# Epoch [234/500], Train Loss: 1.283e-02, Validation Loss: 1.424e+01
# Epoch [235/500], Train Loss: 1.272e-02, Validation Loss: 1.429e+01
# Epoch [236/500], Train Loss: 1.248e-02, Validation Loss: 1.418e+01
# Epoch [237/500], Train Loss: 1.262e-02, Validation Loss: 1.438e+01
# Epoch [238/500], Train Loss: 1.247e-02, Validation Loss: 1.407e+01
# Epoch [239/500], Train Loss: 1.354e-02, Validation Loss: 1.421e+01
# Epoch [240/500], Train Loss: 1.257e-02, Validation Loss: 1.403e+01
# Epoch [241/500], Train Loss: 1.279e-02, Validation Loss: 1.442e+01
# Epoch [242/500], Train Loss: 1.291e-02, Validation Loss: 1.384e+01
# Epoch [243/500], Train Loss: 1.253e-02, Validation Loss: 1.389e+01
# Epoch [244/500], Train Loss: 1.266e-02, Validation Loss: 1.377e+01
# Epoch [245/500], Train Loss: 1.242e-02, Validation Loss: 1.402e+01
# Epoch [246/500], Train Loss: 1.235e-02, Validation Loss: 1.380e+01
# Epoch [247/500], Train Loss: 1.258e-02, Validation Loss: 1.383e+01
# Epoch [248/500], Train Loss: 1.248e-02, Validation Loss: 1.365e+01
# Epoch [249/500], Train Loss: 1.249e-02, Validation Loss: 1.405e+01
# Epoch [250/500], Train Loss: 1.271e-02, Validation Loss: 1.359e+01
# Epoch [251/500], Train Loss: 1.269e-02, Validation Loss: 1.391e+01
# Epoch [252/500], Train Loss: 1.232e-02, Validation Loss: 1.348e+01
# Epoch [253/500], Train Loss: 1.240e-02, Validation Loss: 1.455e+01
# Epoch [254/500], Train Loss: 1.330e-02, Validation Loss: 1.375e+01
# Epoch [255/500], Train Loss: 1.264e-02, Validation Loss: 1.329e+01
# Epoch [256/500], Train Loss: 1.277e-02, Validation Loss: 1.339e+01
# Epoch [257/500], Train Loss: 1.251e-02, Validation Loss: 1.303e+01
# Epoch [258/500], Train Loss: 1.264e-02, Validation Loss: 1.321e+01
# Epoch [259/500], Train Loss: 1.241e-02, Validation Loss: 1.321e+01
# Epoch [260/500], Train Loss: 1.239e-02, Validation Loss: 1.324e+01
# Epoch [261/500], Train Loss: 1.309e-02, Validation Loss: 1.346e+01
# Epoch [262/500], Train Loss: 1.377e-02, Validation Loss: 1.420e+01
# Epoch [263/500], Train Loss: 1.310e-02, Validation Loss: 1.414e+01
# Epoch [264/500], Train Loss: 1.306e-02, Validation Loss: 1.379e+01
# Epoch [265/500], Train Loss: 1.314e-02, Validation Loss: 1.341e+01
# Epoch [266/500], Train Loss: 1.311e-02, Validation Loss: 1.384e+01
# Epoch [267/500], Train Loss: 1.318e-02, Validation Loss: 1.371e+01
# Epoch [268/500], Train Loss: 1.310e-02, Validation Loss: 1.329e+01
# Epoch [269/500], Train Loss: 1.296e-02, Validation Loss: 1.306e+01
# Epoch [270/500], Train Loss: 1.294e-02, Validation Loss: 1.291e+01
# Epoch [271/500], Train Loss: 1.273e-02, Validation Loss: 1.280e+01
# Epoch [272/500], Train Loss: 1.243e-02, Validation Loss: 1.275e+01
# Epoch [273/500], Train Loss: 1.280e-02, Validation Loss: 1.261e+01
# Epoch [274/500], Train Loss: 1.259e-02, Validation Loss: 1.252e+01
# Epoch [275/500], Train Loss: 1.272e-02, Validation Loss: 1.253e+01
# Epoch [276/500], Train Loss: 1.248e-02, Validation Loss: 1.302e+01
# Epoch [277/500], Train Loss: 1.365e-02, Validation Loss: 1.316e+01
# Epoch [278/500], Train Loss: 1.258e-02, Validation Loss: 1.402e+01
# Epoch [279/500], Train Loss: 1.347e-02, Validation Loss: 1.392e+01
# Epoch [280/500], Train Loss: 1.295e-02, Validation Loss: 1.353e+01
# Epoch [281/500], Train Loss: 1.238e-02, Validation Loss: 1.323e+01
# Epoch [282/500], Train Loss: 1.282e-02, Validation Loss: 1.314e+01
# Epoch [283/500], Train Loss: 1.228e-02, Validation Loss: 1.290e+01
# Epoch [284/500], Train Loss: 1.288e-02, Validation Loss: 1.291e+01
# Epoch [285/500], Train Loss: 1.240e-02, Validation Loss: 1.271e+01
# Epoch [286/500], Train Loss: 1.295e-02, Validation Loss: 1.280e+01
# Epoch [287/500], Train Loss: 1.260e-02, Validation Loss: 1.253e+01
# Epoch [288/500], Train Loss: 1.222e-02, Validation Loss: 1.238e+01
# Epoch [289/500], Train Loss: 1.249e-02, Validation Loss: 1.228e+01
# Epoch [290/500], Train Loss: 1.252e-02, Validation Loss: 1.248e+01
# Epoch [291/500], Train Loss: 1.242e-02, Validation Loss: 1.245e+01
# Epoch [292/500], Train Loss: 1.296e-02, Validation Loss: 1.232e+01
# Epoch [293/500], Train Loss: 1.233e-02, Validation Loss: 1.220e+01
# Epoch [294/500], Train Loss: 1.247e-02, Validation Loss: 1.214e+01
# Epoch [295/500], Train Loss: 1.228e-02, Validation Loss: 1.203e+01
# Epoch [296/500], Train Loss: 1.233e-02, Validation Loss: 1.198e+01
# Epoch [297/500], Train Loss: 1.212e-02, Validation Loss: 1.189e+01
# Epoch [298/500], Train Loss: 1.230e-02, Validation Loss: 1.200e+01
# Epoch [299/500], Train Loss: 1.240e-02, Validation Loss: 1.183e+01
# Epoch [300/500], Train Loss: 1.235e-02, Validation Loss: 1.216e+01
# Epoch [301/500], Train Loss: 1.252e-02, Validation Loss: 1.180e+01
# Epoch [302/500], Train Loss: 1.208e-02, Validation Loss: 1.198e+01
# Epoch [303/500], Train Loss: 1.255e-02, Validation Loss: 1.176e+01
# Epoch [304/500], Train Loss: 1.220e-02, Validation Loss: 1.228e+01
# Epoch [305/500], Train Loss: 1.348e-02, Validation Loss: 1.221e+01
# Epoch [306/500], Train Loss: 1.254e-02, Validation Loss: 1.300e+01
# Epoch [307/500], Train Loss: 1.223e-02, Validation Loss: 1.215e+01
# Epoch [308/500], Train Loss: 1.261e-02, Validation Loss: 1.179e+01
# Epoch [309/500], Train Loss: 1.222e-02, Validation Loss: 1.157e+01
# Epoch [310/500], Train Loss: 1.238e-02, Validation Loss: 1.155e+01
# Epoch [311/500], Train Loss: 1.230e-02, Validation Loss: 1.145e+01
# Epoch [312/500], Train Loss: 1.236e-02, Validation Loss: 1.160e+01
# Epoch [313/500], Train Loss: 1.247e-02, Validation Loss: 1.147e+01
# Epoch [314/500], Train Loss: 1.218e-02, Validation Loss: 1.177e+01
# Epoch [315/500], Train Loss: 1.217e-02, Validation Loss: 1.150e+01
# Epoch [316/500], Train Loss: 1.202e-02, Validation Loss: 1.142e+01
# Epoch [317/500], Train Loss: 1.263e-02, Validation Loss: 1.129e+01
# Epoch [318/500], Train Loss: 1.221e-02, Validation Loss: 1.130e+01
# Epoch [319/500], Train Loss: 1.214e-02, Validation Loss: 1.132e+01
# Epoch [320/500], Train Loss: 1.205e-02, Validation Loss: 1.132e+01
# Epoch [321/500], Train Loss: 1.200e-02, Validation Loss: 1.125e+01
# Epoch [322/500], Train Loss: 1.222e-02, Validation Loss: 1.156e+01
# Epoch [323/500], Train Loss: 1.234e-02, Validation Loss: 1.123e+01
# Epoch [324/500], Train Loss: 1.216e-02, Validation Loss: 1.185e+01
# Epoch [325/500], Train Loss: 1.241e-02, Validation Loss: 1.114e+01
# Epoch [326/500], Train Loss: 1.214e-02, Validation Loss: 1.127e+01
# Epoch [327/500], Train Loss: 1.214e-02, Validation Loss: 1.114e+01
# Epoch [328/500], Train Loss: 1.221e-02, Validation Loss: 1.225e+01
# Epoch [329/500], Train Loss: 1.201e-02, Validation Loss: 1.133e+01
# Epoch [330/500], Train Loss: 1.231e-02, Validation Loss: 1.100e+01
# Epoch [331/500], Train Loss: 1.247e-02, Validation Loss: 1.082e+01
# Epoch [332/500], Train Loss: 1.193e-02, Validation Loss: 1.081e+01
# Epoch [333/500], Train Loss: 1.202e-02, Validation Loss: 1.076e+01
# Epoch [334/500], Train Loss: 1.221e-02, Validation Loss: 1.119e+01
# Epoch [335/500], Train Loss: 1.225e-02, Validation Loss: 1.075e+01
# Epoch [336/500], Train Loss: 1.210e-02, Validation Loss: 1.108e+01
# Epoch [337/500], Train Loss: 1.183e-02, Validation Loss: 1.072e+01
# Epoch [338/500], Train Loss: 1.197e-02, Validation Loss: 1.098e+01
# Epoch [339/500], Train Loss: 1.203e-02, Validation Loss: 1.072e+01
# Epoch [340/500], Train Loss: 1.190e-02, Validation Loss: 1.103e+01
# Epoch [341/500], Train Loss: 1.310e-02, Validation Loss: 1.125e+01
# Epoch [342/500], Train Loss: 1.204e-02, Validation Loss: 1.084e+01
# Epoch [343/500], Train Loss: 1.202e-02, Validation Loss: 1.103e+01
# Epoch [344/500], Train Loss: 1.206e-02, Validation Loss: 1.083e+01
# Epoch [345/500], Train Loss: 1.205e-02, Validation Loss: 1.085e+01
# Epoch [346/500], Train Loss: 1.233e-02, Validation Loss: 1.079e+01
# Epoch [347/500], Train Loss: 1.208e-02, Validation Loss: 1.120e+01
# Epoch [348/500], Train Loss: 1.186e-02, Validation Loss: 1.094e+01
# Epoch [349/500], Train Loss: 1.196e-02, Validation Loss: 1.087e+01
# Epoch [350/500], Train Loss: 1.221e-02, Validation Loss: 1.079e+01
# Epoch [351/500], Train Loss: 1.197e-02, Validation Loss: 1.053e+01
# Epoch [352/500], Train Loss: 1.226e-02, Validation Loss: 1.098e+01
# Epoch [353/500], Train Loss: 1.210e-02, Validation Loss: 1.066e+01
# Epoch [354/500], Train Loss: 1.193e-02, Validation Loss: 1.085e+01
# Epoch [355/500], Train Loss: 1.228e-02, Validation Loss: 1.039e+01
# Epoch [356/500], Train Loss: 1.223e-02, Validation Loss: 1.061e+01
# Epoch [357/500], Train Loss: 1.237e-02, Validation Loss: 1.039e+01
# Epoch [358/500], Train Loss: 1.180e-02, Validation Loss: 1.130e+01
# Epoch [359/500], Train Loss: 1.205e-02, Validation Loss: 1.030e+01
# Epoch [360/500], Train Loss: 1.223e-02, Validation Loss: 1.025e+01
# Epoch [361/500], Train Loss: 1.192e-02, Validation Loss: 1.011e+01
# Epoch [362/500], Train Loss: 1.178e-02, Validation Loss: 1.031e+01
# Epoch [363/500], Train Loss: 1.180e-02, Validation Loss: 1.007e+01
# Epoch [364/500], Train Loss: 1.202e-02, Validation Loss: 1.030e+01
# Epoch [365/500], Train Loss: 1.185e-02, Validation Loss: 1.014e+01
# Epoch [366/500], Train Loss: 1.189e-02, Validation Loss: 1.055e+01
# Epoch [367/500], Train Loss: 1.174e-02, Validation Loss: 1.002e+01
# Epoch [368/500], Train Loss: 1.183e-02, Validation Loss: 1.125e+01
# Epoch [369/500], Train Loss: 1.195e-02, Validation Loss: 1.178e+01
# Epoch [370/500], Train Loss: 1.218e-02, Validation Loss: 1.283e+01
# Epoch [371/500], Train Loss: 1.211e-02, Validation Loss: 1.044e+01
# Epoch [372/500], Train Loss: 1.221e-02, Validation Loss: 1.077e+01
# Epoch [373/500], Train Loss: 1.209e-02, Validation Loss: 1.009e+01
# Epoch [374/500], Train Loss: 1.174e-02, Validation Loss: 9.929e+00
# Epoch [375/500], Train Loss: 1.169e-02, Validation Loss: 9.842e+00
# Epoch [376/500], Train Loss: 1.179e-02, Validation Loss: 9.853e+00
# Epoch [377/500], Train Loss: 1.224e-02, Validation Loss: 9.808e+00
# Epoch [378/500], Train Loss: 1.177e-02, Validation Loss: 9.853e+00
# Epoch [379/500], Train Loss: 1.160e-02, Validation Loss: 9.614e+00
# Epoch [380/500], Train Loss: 1.170e-02, Validation Loss: 9.943e+00
# Epoch [381/500], Train Loss: 1.156e-02, Validation Loss: 9.596e+00
# Epoch [382/500], Train Loss: 1.198e-02, Validation Loss: 9.805e+00
# Epoch [383/500], Train Loss: 1.170e-02, Validation Loss: 9.554e+00
# Epoch [384/500], Train Loss: 1.171e-02, Validation Loss: 9.811e+00
# Epoch [385/500], Train Loss: 1.187e-02, Validation Loss: 9.662e+00
# Epoch [386/500], Train Loss: 1.182e-02, Validation Loss: 9.900e+00
# Epoch [387/500], Train Loss: 1.164e-02, Validation Loss: 9.776e+00
# Epoch [388/500], Train Loss: 1.195e-02, Validation Loss: 9.960e+00
# Epoch [389/500], Train Loss: 1.161e-02, Validation Loss: 9.700e+00
# Epoch [390/500], Train Loss: 1.229e-02, Validation Loss: 9.943e+00
# Epoch [391/500], Train Loss: 1.170e-02, Validation Loss: 9.888e+00
# Epoch [392/500], Train Loss: 1.160e-02, Validation Loss: 1.015e+01
# Epoch [393/500], Train Loss: 1.176e-02, Validation Loss: 9.948e+00
# Epoch [394/500], Train Loss: 1.174e-02, Validation Loss: 1.011e+01
# Epoch [395/500], Train Loss: 1.191e-02, Validation Loss: 1.011e+01
# Epoch [396/500], Train Loss: 1.175e-02, Validation Loss: 9.845e+00
# Epoch [397/500], Train Loss: 1.187e-02, Validation Loss: 1.020e+01
# Epoch [398/500], Train Loss: 1.188e-02, Validation Loss: 9.864e+00
# Epoch [399/500], Train Loss: 1.193e-02, Validation Loss: 1.066e+01
# Epoch [400/500], Train Loss: 1.181e-02, Validation Loss: 9.806e+00
# Epoch [401/500], Train Loss: 1.216e-02, Validation Loss: 1.038e+01
# Epoch [402/500], Train Loss: 1.192e-02, Validation Loss: 9.930e+00
# Epoch [403/500], Train Loss: 1.178e-02, Validation Loss: 9.904e+00
# Epoch [404/500], Train Loss: 1.194e-02, Validation Loss: 9.480e+00
# Epoch [405/500], Train Loss: 1.232e-02, Validation Loss: 9.887e+00
# Epoch [406/500], Train Loss: 1.223e-02, Validation Loss: 9.521e+00
# Epoch [407/500], Train Loss: 1.171e-02, Validation Loss: 9.749e+00
# Epoch [408/500], Train Loss: 1.179e-02, Validation Loss: 9.421e+00
# Epoch [409/500], Train Loss: 1.203e-02, Validation Loss: 9.195e+00
# Epoch [410/500], Train Loss: 1.177e-02, Validation Loss: 9.087e+00
# Epoch [411/500], Train Loss: 1.158e-02, Validation Loss: 8.999e+00
# Epoch [412/500], Train Loss: 1.247e-02, Validation Loss: 8.962e+00
# Epoch [413/500], Train Loss: 1.197e-02, Validation Loss: 8.953e+00
# Epoch [414/500], Train Loss: 1.182e-02, Validation Loss: 9.153e+00
# Epoch [415/500], Train Loss: 1.167e-02, Validation Loss: 8.974e+00
# Epoch [416/500], Train Loss: 1.220e-02, Validation Loss: 8.963e+00
# Epoch [417/500], Train Loss: 1.164e-02, Validation Loss: 8.966e+00
# Epoch [418/500], Train Loss: 1.161e-02, Validation Loss: 9.033e+00
# Epoch [419/500], Train Loss: 1.245e-02, Validation Loss: 9.013e+00
# Epoch [420/500], Train Loss: 1.151e-02, Validation Loss: 9.234e+00
# Epoch [421/500], Train Loss: 1.174e-02, Validation Loss: 9.125e+00
# Epoch [422/500], Train Loss: 1.171e-02, Validation Loss: 9.144e+00
# Epoch [423/500], Train Loss: 1.169e-02, Validation Loss: 9.357e+00
# Epoch [424/500], Train Loss: 1.197e-02, Validation Loss: 9.035e+00
# Epoch [425/500], Train Loss: 1.153e-02, Validation Loss: 9.209e+00
# Epoch [426/500], Train Loss: 1.151e-02, Validation Loss: 9.179e+00
# Epoch [427/500], Train Loss: 1.197e-02, Validation Loss: 9.383e+00
# Epoch [428/500], Train Loss: 1.185e-02, Validation Loss: 8.948e+00
# Epoch [429/500], Train Loss: 1.187e-02, Validation Loss: 1.009e+01
# Epoch [430/500], Train Loss: 1.216e-02, Validation Loss: 9.217e+00
# Epoch [431/500], Train Loss: 1.281e-02, Validation Loss: 9.790e+00
# Epoch [432/500], Train Loss: 1.155e-02, Validation Loss: 9.219e+00
# Epoch [433/500], Train Loss: 1.234e-02, Validation Loss: 9.451e+00
# Epoch [434/500], Train Loss: 1.180e-02, Validation Loss: 9.300e+00
# Epoch [435/500], Train Loss: 1.190e-02, Validation Loss: 9.394e+00
# Epoch [436/500], Train Loss: 1.202e-02, Validation Loss: 9.821e+00
# Epoch [437/500], Train Loss: 1.221e-02, Validation Loss: 9.438e+00
# Epoch [438/500], Train Loss: 1.190e-02, Validation Loss: 9.079e+00
# Epoch [439/500], Train Loss: 1.170e-02, Validation Loss: 9.083e+00
# Epoch [440/500], Train Loss: 1.166e-02, Validation Loss: 8.783e+00
# Epoch [441/500], Train Loss: 1.190e-02, Validation Loss: 8.734e+00
# Epoch [442/500], Train Loss: 1.328e-02, Validation Loss: 8.545e+00
# Epoch [443/500], Train Loss: 1.152e-02, Validation Loss: 8.558e+00
# Epoch [444/500], Train Loss: 1.156e-02, Validation Loss: 8.746e+00
# Epoch [445/500], Train Loss: 1.162e-02, Validation Loss: 9.278e+00
# Epoch [446/500], Train Loss: 1.193e-02, Validation Loss: 8.806e+00
# Epoch [447/500], Train Loss: 1.201e-02, Validation Loss: 8.697e+00
# Epoch [448/500], Train Loss: 1.149e-02, Validation Loss: 8.446e+00
# Epoch [449/500], Train Loss: 1.150e-02, Validation Loss: 8.405e+00
# Epoch [450/500], Train Loss: 1.133e-02, Validation Loss: 8.327e+00
# Epoch [451/500], Train Loss: 1.226e-02, Validation Loss: 8.380e+00
# Epoch [452/500], Train Loss: 1.154e-02, Validation Loss: 8.539e+00
# Epoch [453/500], Train Loss: 1.154e-02, Validation Loss: 8.760e+00
# Epoch [454/500], Train Loss: 1.161e-02, Validation Loss: 8.445e+00
# Epoch [455/500], Train Loss: 1.144e-02, Validation Loss: 8.373e+00
# Epoch [456/500], Train Loss: 1.142e-02, Validation Loss: 8.345e+00
# Epoch [457/500], Train Loss: 1.180e-02, Validation Loss: 8.248e+00
# Epoch [458/500], Train Loss: 1.141e-02, Validation Loss: 8.273e+00
# Epoch [459/500], Train Loss: 1.129e-02, Validation Loss: 8.174e+00
# Epoch [460/500], Train Loss: 1.151e-02, Validation Loss: 8.288e+00
# Epoch [461/500], Train Loss: 1.158e-02, Validation Loss: 8.165e+00
# Epoch [462/500], Train Loss: 1.183e-02, Validation Loss: 8.486e+00
# Epoch [463/500], Train Loss: 1.175e-02, Validation Loss: 8.395e+00
# Epoch [464/500], Train Loss: 1.166e-02, Validation Loss: 8.593e+00
# Epoch [465/500], Train Loss: 1.171e-02, Validation Loss: 8.272e+00
# Epoch [466/500], Train Loss: 1.131e-02, Validation Loss: 8.508e+00
# Epoch [467/500], Train Loss: 1.133e-02, Validation Loss: 8.464e+00
# Epoch [468/500], Train Loss: 1.131e-02, Validation Loss: 8.482e+00
# Epoch [469/500], Train Loss: 1.127e-02, Validation Loss: 8.296e+00
# Epoch [470/500], Train Loss: 1.143e-02, Validation Loss: 8.681e+00
# Epoch [471/500], Train Loss: 1.168e-02, Validation Loss: 8.474e+00
# Epoch [472/500], Train Loss: 1.138e-02, Validation Loss: 8.265e+00
# Epoch [473/500], Train Loss: 1.219e-02, Validation Loss: 8.698e+00
# Epoch [474/500], Train Loss: 1.135e-02, Validation Loss: 8.669e+00
# Epoch [475/500], Train Loss: 1.134e-02, Validation Loss: 8.378e+00
# Epoch [476/500], Train Loss: 1.177e-02, Validation Loss: 8.578e+00
# Epoch [477/500], Train Loss: 1.144e-02, Validation Loss: 8.203e+00
# Epoch [478/500], Train Loss: 1.131e-02, Validation Loss: 8.304e+00
# Epoch [479/500], Train Loss: 1.140e-02, Validation Loss: 8.207e+00
# Epoch [480/500], Train Loss: 1.156e-02, Validation Loss: 8.379e+00
# Epoch [481/500], Train Loss: 1.233e-02, Validation Loss: 8.122e+00
# Epoch [482/500], Train Loss: 1.201e-02, Validation Loss: 8.085e+00
# Epoch [483/500], Train Loss: 1.138e-02, Validation Loss: 8.047e+00
# Epoch [484/500], Train Loss: 1.197e-02, Validation Loss: 8.050e+00
# Epoch [485/500], Train Loss: 1.120e-02, Validation Loss: 7.998e+00
# Epoch [486/500], Train Loss: 1.123e-02, Validation Loss: 8.117e+00
# Epoch [487/500], Train Loss: 1.195e-02, Validation Loss: 8.080e+00
# Epoch [488/500], Train Loss: 1.115e-02, Validation Loss: 8.205e+00
# Epoch [489/500], Train Loss: 1.150e-02, Validation Loss: 7.983e+00
# Epoch [490/500], Train Loss: 1.135e-02, Validation Loss: 8.314e+00
# Epoch [491/500], Train Loss: 1.149e-02, Validation Loss: 8.082e+00
# Epoch [492/500], Train Loss: 1.121e-02, Validation Loss: 8.381e+00
# Epoch [493/500], Train Loss: 1.120e-02, Validation Loss: 8.017e+00
# Epoch [494/500], Train Loss: 1.157e-02, Validation Loss: 8.668e+00
# Epoch [495/500], Train Loss: 1.177e-02, Validation Loss: 8.292e+00
# Epoch [496/500], Train Loss: 1.136e-02, Validation Loss: 8.319e+00
# Epoch [497/500], Train Loss: 1.131e-02, Validation Loss: 8.193e+00
# Epoch [498/500], Train Loss: 1.179e-02, Validation Loss: 7.999e+00
# Epoch [499/500], Train Loss: 1.135e-02, Validation Loss: 8.373e+00
# Epoch [500/500], Train Loss: 1.132e-02, Validation Loss: 8.205e+00

# %%
# Train the model AGAIN
learning_rate = 1e-4
num_epochs = 500
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    running_loss = 0.0
    running_val_loss = 0.0
    for xx,yy,tt  in train_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        optimizer.zero_grad()
        outputs = model(xx, tt*0.)
        
        theta_misfit = criterion(outputs[:,:,0:1,:,:], yy[:,:,0:1,:,:])/criterion(outputs[:,:,0:1,:,:]*0., yy[:,:,0:1,:,:])  
        ustar_misfit = criterion(outputs[:,:,1:2,:,:], yy[:,:,1:2,:,:])/criterion(outputs[:,:,1:2,:,:]*0., yy[:,:,1:2,:,:]) 
        xi_f_misfit = criterion(outputs[:,:,2:3,:,:], yy[:,:,2:3,:,:])/criterion(outputs[:,:,2:3,:,:]*0., yy[:,:,2:3,:,:])
        
        loss = theta_misfit + ustar_misfit + xi_f_misfit
        
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    for xx,yy,tt  in test_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        optimizer.zero_grad()
        outputs = model(xx, tt*0.)
        
        theta_misfit = criterion(outputs[:,:,0:1,:,:], yy[:,:,0:1,:,:])/criterion(outputs[:,:,0:1,:,:]*0., yy[:,:,0:1,:,:])  
        ustar_misfit = criterion(outputs[:,:,1:2,:,:], yy[:,:,1:2,:,:])/criterion(outputs[:,:,1:2,:,:]*0., yy[:,:,1:2,:,:]) 
        xi_f_misfit = criterion(outputs[:,:,2:3,:,:], yy[:,:,2:3,:,:])/criterion(outputs[:,:,2:3,:,:]*0., yy[:,:,2:3,:,:])
        
        loss = theta_misfit + ustar_misfit + xi_f_misfit
        
        loss.backward()
        optimizer.step()
    
    for xx,yy,tt  in test_loader:
        xx = xx.to(device)
        yy = yy.to(device)
        tt = tt.to(device)
        with torch.no_grad():
            outputs = model(xx, tt*0.)
        
            val_loss = criterion(outputs, yy)
        running_val_loss += val_loss.item()
    
    trn_loss = running_loss/len(train_loader)
    val_loss = running_val_loss/len(test_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {trn_loss:.3e}, Validation Loss: {val_loss:.3e}")
    
    train_loss.append(trn_loss)
    validation_loss.append(val_loss)
    
    if val_loss <= best_loss:
        best_model.load_state_dict(model.state_dict())
        torch.save(best_model, 'best_model.pth')
        best_epoch = epoch
        best_loss = val_loss
# Out:
# Epoch [1/500], Train Loss: 1.151e-02, Validation Loss: 1.070e+01
# Epoch [2/500], Train Loss: 1.149e-02, Validation Loss: 9.318e+00
# Epoch [3/500], Train Loss: 1.110e-02, Validation Loss: 8.941e+00
# Epoch [4/500], Train Loss: 1.117e-02, Validation Loss: 8.707e+00
# Epoch [5/500], Train Loss: 1.103e-02, Validation Loss: 8.631e+00
# Epoch [6/500], Train Loss: 1.117e-02, Validation Loss: 8.840e+00
# Epoch [7/500], Train Loss: 1.171e-02, Validation Loss: 9.011e+00
# Epoch [8/500], Train Loss: 1.109e-02, Validation Loss: 9.120e+00
# Epoch [9/500], Train Loss: 1.111e-02, Validation Loss: 8.808e+00
# Epoch [10/500], Train Loss: 1.130e-02, Validation Loss: 9.052e+00
# Epoch [11/500], Train Loss: 1.158e-02, Validation Loss: 8.851e+00
# Epoch [12/500], Train Loss: 1.149e-02, Validation Loss: 8.541e+00
# Epoch [13/500], Train Loss: 1.131e-02, Validation Loss: 8.697e+00
# Epoch [14/500], Train Loss: 1.174e-02, Validation Loss: 8.437e+00
# Epoch [15/500], Train Loss: 1.118e-02, Validation Loss: 8.386e+00
# Epoch [16/500], Train Loss: 1.105e-02, Validation Loss: 8.203e+00
# Epoch [17/500], Train Loss: 1.132e-02, Validation Loss: 8.916e+00
# Epoch [18/500], Train Loss: 1.111e-02, Validation Loss: 8.378e+00
# Epoch [19/500], Train Loss: 1.116e-02, Validation Loss: 8.492e+00
# Epoch [20/500], Train Loss: 1.146e-02, Validation Loss: 8.452e+00
# Epoch [21/500], Train Loss: 1.124e-02, Validation Loss: 8.417e+00
# Epoch [22/500], Train Loss: 1.113e-02, Validation Loss: 8.108e+00
# Epoch [23/500], Train Loss: 1.133e-02, Validation Loss: 8.122e+00
# Epoch [24/500], Train Loss: 1.124e-02, Validation Loss: 8.003e+00
# Epoch [25/500], Train Loss: 1.109e-02, Validation Loss: 7.894e+00
# Epoch [26/500], Train Loss: 1.150e-02, Validation Loss: 7.929e+00
# Epoch [27/500], Train Loss: 1.114e-02, Validation Loss: 7.953e+00
# Epoch [28/500], Train Loss: 1.127e-02, Validation Loss: 7.862e+00
# Epoch [29/500], Train Loss: 1.128e-02, Validation Loss: 8.187e+00
# Epoch [30/500], Train Loss: 1.338e-02, Validation Loss: 7.964e+00
# Epoch [31/500], Train Loss: 1.092e-02, Validation Loss: 8.309e+00
# Epoch [32/500], Train Loss: 1.119e-02, Validation Loss: 8.079e+00
# Epoch [33/500], Train Loss: 1.093e-02, Validation Loss: 8.304e+00
# Epoch [34/500], Train Loss: 1.199e-02, Validation Loss: 8.025e+00
# Epoch [35/500], Train Loss: 1.136e-02, Validation Loss: 8.623e+00
# Epoch [36/500], Train Loss: 1.118e-02, Validation Loss: 8.501e+00
# Epoch [37/500], Train Loss: 1.164e-02, Validation Loss: 8.611e+00
# Epoch [38/500], Train Loss: 1.145e-02, Validation Loss: 8.666e+00
# Epoch [39/500], Train Loss: 1.132e-02, Validation Loss: 8.440e+00
# Epoch [40/500], Train Loss: 1.133e-02, Validation Loss: 8.718e+00
# Epoch [41/500], Train Loss: 1.153e-02, Validation Loss: 9.812e+00
# Epoch [42/500], Train Loss: 1.133e-02, Validation Loss: 8.930e+00
# Epoch [43/500], Train Loss: 1.159e-02, Validation Loss: 8.297e+00
# Epoch [44/500], Train Loss: 1.115e-02, Validation Loss: 8.114e+00
# Epoch [45/500], Train Loss: 1.147e-02, Validation Loss: 7.921e+00
# Epoch [46/500], Train Loss: 1.113e-02, Validation Loss: 8.090e+00
# Epoch [47/500], Train Loss: 1.142e-02, Validation Loss: 7.792e+00
# Epoch [48/500], Train Loss: 1.125e-02, Validation Loss: 8.206e+00
# Epoch [49/500], Train Loss: 1.165e-02, Validation Loss: 7.703e+00
# Epoch [50/500], Train Loss: 1.121e-02, Validation Loss: 7.803e+00
# Epoch [51/500], Train Loss: 1.139e-02, Validation Loss: 7.646e+00
# Epoch [52/500], Train Loss: 1.100e-02, Validation Loss: 7.583e+00
# Epoch [53/500], Train Loss: 1.115e-02, Validation Loss: 7.688e+00
# Epoch [54/500], Train Loss: 1.134e-02, Validation Loss: 8.434e+00
# Epoch [55/500], Train Loss: 1.164e-02, Validation Loss: 8.221e+00
# Epoch [56/500], Train Loss: 1.112e-02, Validation Loss: 8.049e+00
# Epoch [57/500], Train Loss: 1.134e-02, Validation Loss: 8.197e+00
# Epoch [58/500], Train Loss: 1.129e-02, Validation Loss: 7.883e+00
# Epoch [59/500], Train Loss: 1.114e-02, Validation Loss: 7.694e+00
# Epoch [60/500], Train Loss: 1.147e-02, Validation Loss: 7.569e+00
# Epoch [61/500], Train Loss: 1.094e-02, Validation Loss: 7.539e+00
# Epoch [62/500], Train Loss: 1.095e-02, Validation Loss: 7.464e+00
# Epoch [63/500], Train Loss: 1.090e-02, Validation Loss: 7.448e+00
# Epoch [64/500], Train Loss: 1.159e-02, Validation Loss: 7.388e+00
# Epoch [65/500], Train Loss: 1.125e-02, Validation Loss: 7.454e+00
# Epoch [66/500], Train Loss: 1.094e-02, Validation Loss: 7.395e+00
# Epoch [67/500], Train Loss: 1.091e-02, Validation Loss: 7.654e+00
# Epoch [68/500], Train Loss: 1.118e-02, Validation Loss: 7.404e+00
# Epoch [69/500], Train Loss: 1.091e-02, Validation Loss: 7.601e+00
# Epoch [70/500], Train Loss: 1.093e-02, Validation Loss: 7.384e+00
# Epoch [71/500], Train Loss: 1.101e-02, Validation Loss: 7.966e+00
# Epoch [72/500], Train Loss: 1.138e-02, Validation Loss: 7.511e+00
# Epoch [73/500], Train Loss: 1.112e-02, Validation Loss: 7.805e+00
# Epoch [74/500], Train Loss: 1.138e-02, Validation Loss: 7.598e+00
# Epoch [75/500], Train Loss: 1.135e-02, Validation Loss: 8.049e+00
# Epoch [76/500], Train Loss: 1.153e-02, Validation Loss: 7.426e+00
# Epoch [77/500], Train Loss: 1.122e-02, Validation Loss: 7.314e+00
# Epoch [78/500], Train Loss: 1.093e-02, Validation Loss: 7.241e+00
# Epoch [79/500], Train Loss: 1.089e-02, Validation Loss: 7.326e+00
# Epoch [80/500], Train Loss: 1.132e-02, Validation Loss: 7.212e+00
# Epoch [81/500], Train Loss: 1.162e-02, Validation Loss: 7.611e+00
# Epoch [82/500], Train Loss: 1.111e-02, Validation Loss: 7.335e+00
# Epoch [83/500], Train Loss: 1.109e-02, Validation Loss: 8.793e+00
# Epoch [84/500], Train Loss: 1.109e-02, Validation Loss: 7.508e+00
# Epoch [85/500], Train Loss: 1.095e-02, Validation Loss: 7.385e+00
# Epoch [86/500], Train Loss: 1.096e-02, Validation Loss: 7.316e+00
# Epoch [87/500], Train Loss: 1.150e-02, Validation Loss: 7.284e+00
# Epoch [88/500], Train Loss: 1.129e-02, Validation Loss: 7.139e+00
# Epoch [89/500], Train Loss: 1.098e-02, Validation Loss: 7.540e+00
# Epoch [90/500], Train Loss: 1.091e-02, Validation Loss: 7.173e+00
# Epoch [91/500], Train Loss: 1.134e-02, Validation Loss: 7.500e+00
# Epoch [92/500], Train Loss: 1.146e-02, Validation Loss: 7.297e+00
# Epoch [93/500], Train Loss: 1.194e-02, Validation Loss: 7.719e+00
# Epoch [94/500], Train Loss: 1.136e-02, Validation Loss: 7.502e+00
# Epoch [95/500], Train Loss: 1.209e-02, Validation Loss: 7.629e+00
# Epoch [96/500], Train Loss: 1.109e-02, Validation Loss: 7.320e+00
# Epoch [97/500], Train Loss: 1.137e-02, Validation Loss: 7.729e+00
# Epoch [98/500], Train Loss: 1.172e-02, Validation Loss: 7.472e+00
# Epoch [99/500], Train Loss: 1.151e-02, Validation Loss: 7.518e+00
# Epoch [100/500], Train Loss: 1.105e-02, Validation Loss: 7.645e+00
# Epoch [101/500], Train Loss: 1.190e-02, Validation Loss: 7.541e+00
# Epoch [102/500], Train Loss: 1.122e-02, Validation Loss: 8.531e+00
# Epoch [103/500], Train Loss: 1.114e-02, Validation Loss: 7.958e+00
# Epoch [104/500], Train Loss: 1.105e-02, Validation Loss: 7.462e+00
# Epoch [105/500], Train Loss: 1.144e-02, Validation Loss: 7.241e+00
# Epoch [106/500], Train Loss: 1.102e-02, Validation Loss: 6.983e+00
# Epoch [107/500], Train Loss: 1.160e-02, Validation Loss: 6.890e+00
# Epoch [108/500], Train Loss: 1.194e-02, Validation Loss: 6.775e+00
# Epoch [109/500], Train Loss: 1.084e-02, Validation Loss: 6.815e+00
# Epoch [110/500], Train Loss: 1.148e-02, Validation Loss: 6.739e+00
# Epoch [111/500], Train Loss: 1.085e-02, Validation Loss: 6.709e+00
# Epoch [112/500], Train Loss: 1.109e-02, Validation Loss: 6.662e+00
# Epoch [113/500], Train Loss: 1.082e-02, Validation Loss: 6.683e+00
# Epoch [114/500], Train Loss: 1.104e-02, Validation Loss: 6.658e+00
# Epoch [115/500], Train Loss: 1.176e-02, Validation Loss: 6.704e+00
# Epoch [116/500], Train Loss: 1.121e-02, Validation Loss: 6.660e+00
# Epoch [117/500], Train Loss: 1.095e-02, Validation Loss: 6.888e+00
# Epoch [118/500], Train Loss: 1.128e-02, Validation Loss: 6.844e+00
# Epoch [119/500], Train Loss: 1.087e-02, Validation Loss: 7.147e+00
# Epoch [120/500], Train Loss: 1.141e-02, Validation Loss: 7.092e+00
# Epoch [121/500], Train Loss: 1.097e-02, Validation Loss: 8.937e+00
# Epoch [122/500], Train Loss: 1.143e-02, Validation Loss: 7.143e+00
# Epoch [123/500], Train Loss: 1.108e-02, Validation Loss: 7.094e+00
# Epoch [124/500], Train Loss: 1.136e-02, Validation Loss: 6.800e+00
# Epoch [125/500], Train Loss: 1.085e-02, Validation Loss: 6.628e+00
# Epoch [126/500], Train Loss: 1.114e-02, Validation Loss: 6.919e+00
# Epoch [127/500], Train Loss: 1.141e-02, Validation Loss: 6.562e+00
# Epoch [128/500], Train Loss: 1.105e-02, Validation Loss: 6.693e+00
# Epoch [129/500], Train Loss: 1.096e-02, Validation Loss: 6.539e+00
# Epoch [130/500], Train Loss: 1.129e-02, Validation Loss: 6.547e+00
# Epoch [131/500], Train Loss: 1.102e-02, Validation Loss: 6.522e+00
# Epoch [132/500], Train Loss: 1.136e-02, Validation Loss: 6.508e+00
# Epoch [133/500], Train Loss: 1.092e-02, Validation Loss: 6.498e+00
# Epoch [134/500], Train Loss: 1.094e-02, Validation Loss: 6.604e+00
# Epoch [135/500], Train Loss: 1.138e-02, Validation Loss: 6.565e+00
# Epoch [136/500], Train Loss: 1.095e-02, Validation Loss: 6.809e+00
# Epoch [137/500], Train Loss: 1.107e-02, Validation Loss: 6.542e+00
# Epoch [138/500], Train Loss: 1.076e-02, Validation Loss: 7.156e+00
# Epoch [139/500], Train Loss: 1.156e-02, Validation Loss: 7.031e+00
# Epoch [140/500], Train Loss: 1.115e-02, Validation Loss: 7.917e+00
# Epoch [141/500], Train Loss: 1.132e-02, Validation Loss: 8.718e+00
# Epoch [142/500], Train Loss: 1.162e-02, Validation Loss: 8.140e+00
# Epoch [143/500], Train Loss: 1.161e-02, Validation Loss: 7.929e+00
# Epoch [144/500], Train Loss: 1.106e-02, Validation Loss: 7.250e+00
# Epoch [145/500], Train Loss: 1.113e-02, Validation Loss: 7.271e+00
# Epoch [146/500], Train Loss: 1.113e-02, Validation Loss: 6.849e+00
# Epoch [147/500], Train Loss: 1.127e-02, Validation Loss: 6.944e+00
# Epoch [148/500], Train Loss: 1.096e-02, Validation Loss: 6.699e+00
# Epoch [149/500], Train Loss: 1.138e-02, Validation Loss: 6.743e+00
# Epoch [150/500], Train Loss: 1.099e-02, Validation Loss: 6.549e+00
# Epoch [151/500], Train Loss: 1.107e-02, Validation Loss: 6.474e+00
# Epoch [152/500], Train Loss: 1.108e-02, Validation Loss: 6.505e+00
# Epoch [153/500], Train Loss: 1.126e-02, Validation Loss: 6.728e+00
# Epoch [154/500], Train Loss: 1.111e-02, Validation Loss: 6.699e+00
# Epoch [155/500], Train Loss: 1.109e-02, Validation Loss: 6.577e+00
# Epoch [156/500], Train Loss: 1.169e-02, Validation Loss: 6.406e+00
# Epoch [157/500], Train Loss: 1.083e-02, Validation Loss: 6.491e+00
# Epoch [158/500], Train Loss: 1.095e-02, Validation Loss: 6.293e+00
# Epoch [159/500], Train Loss: 1.124e-02, Validation Loss: 6.280e+00
# Epoch [160/500], Train Loss: 1.075e-02, Validation Loss: 6.213e+00
# Epoch [161/500], Train Loss: 1.071e-02, Validation Loss: 6.347e+00
# Epoch [162/500], Train Loss: 1.118e-02, Validation Loss: 6.354e+00
# Epoch [163/500], Train Loss: 1.137e-02, Validation Loss: 6.482e+00
# Epoch [164/500], Train Loss: 1.107e-02, Validation Loss: 6.523e+00
# Epoch [165/500], Train Loss: 1.108e-02, Validation Loss: 6.502e+00
# Epoch [166/500], Train Loss: 1.099e-02, Validation Loss: 7.140e+00
# Epoch [167/500], Train Loss: 1.091e-02, Validation Loss: 7.335e+00
# Epoch [168/500], Train Loss: 1.114e-02, Validation Loss: 7.324e+00
# Epoch [169/500], Train Loss: 1.087e-02, Validation Loss: 6.595e+00
# Epoch [170/500], Train Loss: 1.106e-02, Validation Loss: 6.628e+00
# Epoch [171/500], Train Loss: 1.083e-02, Validation Loss: 6.432e+00
# Epoch [172/500], Train Loss: 1.103e-02, Validation Loss: 6.377e+00
# Epoch [173/500], Train Loss: 1.107e-02, Validation Loss: 6.308e+00
# Epoch [174/500], Train Loss: 1.094e-02, Validation Loss: 6.313e+00
# Epoch [175/500], Train Loss: 1.082e-02, Validation Loss: 6.302e+00
# Epoch [176/500], Train Loss: 1.139e-02, Validation Loss: 6.257e+00
# Epoch [177/500], Train Loss: 1.105e-02, Validation Loss: 6.465e+00
# Epoch [178/500], Train Loss: 1.104e-02, Validation Loss: 6.292e+00
# Epoch [179/500], Train Loss: 1.106e-02, Validation Loss: 6.295e+00
# Epoch [180/500], Train Loss: 1.078e-02, Validation Loss: 6.350e+00
# Epoch [181/500], Train Loss: 1.075e-02, Validation Loss: 6.279e+00
# Epoch [182/500], Train Loss: 1.109e-02, Validation Loss: 6.752e+00
# Epoch [183/500], Train Loss: 1.114e-02, Validation Loss: 6.280e+00
# Epoch [184/500], Train Loss: 1.103e-02, Validation Loss: 6.396e+00
# Epoch [185/500], Train Loss: 1.076e-02, Validation Loss: 6.331e+00
# Epoch [186/500], Train Loss: 1.092e-02, Validation Loss: 6.460e+00
# Epoch [187/500], Train Loss: 1.073e-02, Validation Loss: 6.382e+00
# Epoch [188/500], Train Loss: 1.107e-02, Validation Loss: 6.764e+00
# Epoch [189/500], Train Loss: 1.136e-02, Validation Loss: 6.478e+00
# Epoch [190/500], Train Loss: 1.104e-02, Validation Loss: 6.623e+00
# Epoch [191/500], Train Loss: 1.119e-02, Validation Loss: 6.320e+00
# Epoch [192/500], Train Loss: 1.126e-02, Validation Loss: 7.389e+00
# Epoch [193/500], Train Loss: 1.086e-02, Validation Loss: 6.624e+00
# Epoch [194/500], Train Loss: 1.101e-02, Validation Loss: 6.683e+00
# Epoch [195/500], Train Loss: 1.088e-02, Validation Loss: 6.343e+00
# Epoch [196/500], Train Loss: 1.097e-02, Validation Loss: 6.985e+00
# Epoch [197/500], Train Loss: 1.097e-02, Validation Loss: 6.421e+00
# Epoch [198/500], Train Loss: 1.076e-02, Validation Loss: 6.459e+00
# Epoch [199/500], Train Loss: 1.096e-02, Validation Loss: 6.332e+00
# Epoch [200/500], Train Loss: 1.089e-02, Validation Loss: 6.685e+00
# Epoch [201/500], Train Loss: 1.121e-02, Validation Loss: 6.630e+00
# Epoch [202/500], Train Loss: 1.100e-02, Validation Loss: 7.015e+00
# Epoch [203/500], Train Loss: 1.089e-02, Validation Loss: 6.532e+00
# Epoch [204/500], Train Loss: 1.103e-02, Validation Loss: 6.546e+00
# Epoch [205/500], Train Loss: 1.081e-02, Validation Loss: 6.425e+00
# Epoch [206/500], Train Loss: 1.076e-02, Validation Loss: 6.402e+00
# Epoch [207/500], Train Loss: 1.087e-02, Validation Loss: 6.154e+00
# Epoch [208/500], Train Loss: 1.085e-02, Validation Loss: 5.997e+00
# Epoch [209/500], Train Loss: 1.076e-02, Validation Loss: 5.974e+00
# Epoch [210/500], Train Loss: 1.111e-02, Validation Loss: 6.048e+00
# Epoch [211/500], Train Loss: 1.086e-02, Validation Loss: 6.047e+00
# Epoch [212/500], Train Loss: 1.069e-02, Validation Loss: 6.122e+00
# Epoch [213/500], Train Loss: 1.108e-02, Validation Loss: 6.352e+00
# Epoch [214/500], Train Loss: 1.092e-02, Validation Loss: 6.777e+00
# Epoch [215/500], Train Loss: 1.177e-02, Validation Loss: 8.148e+00
# Epoch [216/500], Train Loss: 1.227e-02, Validation Loss: 7.327e+00
# Epoch [217/500], Train Loss: 1.161e-02, Validation Loss: 6.794e+00
# Epoch [218/500], Train Loss: 1.131e-02, Validation Loss: 6.417e+00
# Epoch [219/500], Train Loss: 1.133e-02, Validation Loss: 6.448e+00
# Epoch [220/500], Train Loss: 1.201e-02, Validation Loss: 6.215e+00
# Epoch [221/500], Train Loss: 1.107e-02, Validation Loss: 6.085e+00
# Epoch [222/500], Train Loss: 1.095e-02, Validation Loss: 6.054e+00
# Epoch [223/500], Train Loss: 1.102e-02, Validation Loss: 6.272e+00
# Epoch [224/500], Train Loss: 1.088e-02, Validation Loss: 6.297e+00
# Epoch [225/500], Train Loss: 1.087e-02, Validation Loss: 6.003e+00
# Epoch [226/500], Train Loss: 1.079e-02, Validation Loss: 5.896e+00
# Epoch [227/500], Train Loss: 1.075e-02, Validation Loss: 5.800e+00
# Epoch [228/500], Train Loss: 1.071e-02, Validation Loss: 5.754e+00
# Epoch [229/500], Train Loss: 1.085e-02, Validation Loss: 5.856e+00
# Epoch [230/500], Train Loss: 1.085e-02, Validation Loss: 5.966e+00
# Epoch [231/500], Train Loss: 1.084e-02, Validation Loss: 5.929e+00
# Epoch [232/500], Train Loss: 1.084e-02, Validation Loss: 5.916e+00
# Epoch [233/500], Train Loss: 1.079e-02, Validation Loss: 5.757e+00
# Epoch [234/500], Train Loss: 1.065e-02, Validation Loss: 5.724e+00
# Epoch [235/500], Train Loss: 1.081e-02, Validation Loss: 5.664e+00
# Epoch [236/500], Train Loss: 1.079e-02, Validation Loss: 5.669e+00
# Epoch [237/500], Train Loss: 1.063e-02, Validation Loss: 5.629e+00
# Epoch [238/500], Train Loss: 1.062e-02, Validation Loss: 5.640e+00
# Epoch [239/500], Train Loss: 1.087e-02, Validation Loss: 5.614e+00
# Epoch [240/500], Train Loss: 1.109e-02, Validation Loss: 5.629e+00
# Epoch [241/500], Train Loss: 1.073e-02, Validation Loss: 6.470e+00
# Epoch [242/500], Train Loss: 1.098e-02, Validation Loss: 6.515e+00
# Epoch [243/500], Train Loss: 1.119e-02, Validation Loss: 6.085e+00
# Epoch [244/500], Train Loss: 1.096e-02, Validation Loss: 6.525e+00
# Epoch [245/500], Train Loss: 1.085e-02, Validation Loss: 5.834e+00
# Epoch [246/500], Train Loss: 1.082e-02, Validation Loss: 6.064e+00
# Epoch [247/500], Train Loss: 1.093e-02, Validation Loss: 5.873e+00
# Epoch [248/500], Train Loss: 1.068e-02, Validation Loss: 5.696e+00
# Epoch [249/500], Train Loss: 1.064e-02, Validation Loss: 5.694e+00
# Epoch [250/500], Train Loss: 1.084e-02, Validation Loss: 5.729e+00
# Epoch [251/500], Train Loss: 1.155e-02, Validation Loss: 5.677e+00
# Epoch [252/500], Train Loss: 1.060e-02, Validation Loss: 5.601e+00
# Epoch [253/500], Train Loss: 1.107e-02, Validation Loss: 5.712e+00
# Epoch [254/500], Train Loss: 1.102e-02, Validation Loss: 5.654e+00
# Epoch [255/500], Train Loss: 1.086e-02, Validation Loss: 5.583e+00
# Epoch [256/500], Train Loss: 1.063e-02, Validation Loss: 5.544e+00
# Epoch [257/500], Train Loss: 1.057e-02, Validation Loss: 5.543e+00
# Epoch [258/500], Train Loss: 1.076e-02, Validation Loss: 5.510e+00
# Epoch [259/500], Train Loss: 1.116e-02, Validation Loss: 5.553e+00
# Epoch [260/500], Train Loss: 1.078e-02, Validation Loss: 5.542e+00
# Epoch [261/500], Train Loss: 1.068e-02, Validation Loss: 5.598e+00
# Epoch [262/500], Train Loss: 1.133e-02, Validation Loss: 5.518e+00
# Epoch [263/500], Train Loss: 1.054e-02, Validation Loss: 5.618e+00
# Epoch [264/500], Train Loss: 1.115e-02, Validation Loss: 5.546e+00
# Epoch [265/500], Train Loss: 1.071e-02, Validation Loss: 5.879e+00
# Epoch [266/500], Train Loss: 1.080e-02, Validation Loss: 5.695e+00
# Epoch [267/500], Train Loss: 1.074e-02, Validation Loss: 6.225e+00
# Epoch [268/500], Train Loss: 1.062e-02, Validation Loss: 5.748e+00
# Epoch [269/500], Train Loss: 1.074e-02, Validation Loss: 5.985e+00
# Epoch [270/500], Train Loss: 1.104e-02, Validation Loss: 5.716e+00
# Epoch [271/500], Train Loss: 1.130e-02, Validation Loss: 5.687e+00
# Epoch [272/500], Train Loss: 1.060e-02, Validation Loss: 5.583e+00
# Epoch [273/500], Train Loss: 1.089e-02, Validation Loss: 5.606e+00
# Epoch [274/500], Train Loss: 1.098e-02, Validation Loss: 5.658e+00
# Epoch [275/500], Train Loss: 1.090e-02, Validation Loss: 5.680e+00
# Epoch [276/500], Train Loss: 1.068e-02, Validation Loss: 5.813e+00
# Epoch [277/500], Train Loss: 1.148e-02, Validation Loss: 5.881e+00
# Epoch [278/500], Train Loss: 1.055e-02, Validation Loss: 6.124e+00
# Epoch [279/500], Train Loss: 1.056e-02, Validation Loss: 5.909e+00
# Epoch [280/500], Train Loss: 1.095e-02, Validation Loss: 5.594e+00
# Epoch [281/500], Train Loss: 1.083e-02, Validation Loss: 5.612e+00
# Epoch [282/500], Train Loss: 1.058e-02, Validation Loss: 6.078e+00
# Epoch [283/500], Train Loss: 1.086e-02, Validation Loss: 5.848e+00
# Epoch [284/500], Train Loss: 1.073e-02, Validation Loss: 6.092e+00
# Epoch [285/500], Train Loss: 1.075e-02, Validation Loss: 6.052e+00
# Epoch [286/500], Train Loss: 1.093e-02, Validation Loss: 5.784e+00
# Epoch [287/500], Train Loss: 1.163e-02, Validation Loss: 5.719e+00
# Epoch [288/500], Train Loss: 1.059e-02, Validation Loss: 6.070e+00
# Epoch [289/500], Train Loss: 1.119e-02, Validation Loss: 5.720e+00
# Epoch [290/500], Train Loss: 1.114e-02, Validation Loss: 5.724e+00
# Epoch [291/500], Train Loss: 1.087e-02, Validation Loss: 5.900e+00
# Epoch [292/500], Train Loss: 1.077e-02, Validation Loss: 5.691e+00
# Epoch [293/500], Train Loss: 1.077e-02, Validation Loss: 5.679e+00
# Epoch [294/500], Train Loss: 1.066e-02, Validation Loss: 5.751e+00
# Epoch [295/500], Train Loss: 1.073e-02, Validation Loss: 5.698e+00
# Epoch [296/500], Train Loss: 1.055e-02, Validation Loss: 5.831e+00
# Epoch [297/500], Train Loss: 1.078e-02, Validation Loss: 5.727e+00
# Epoch [298/500], Train Loss: 1.055e-02, Validation Loss: 5.924e+00
# Epoch [299/500], Train Loss: 1.087e-02, Validation Loss: 5.679e+00
# Epoch [300/500], Train Loss: 1.055e-02, Validation Loss: 6.203e+00
# Epoch [301/500], Train Loss: 1.071e-02, Validation Loss: 5.949e+00
# Epoch [302/500], Train Loss: 1.066e-02, Validation Loss: 5.839e+00
# Epoch [303/500], Train Loss: 1.072e-02, Validation Loss: 6.325e+00
# Epoch [304/500], Train Loss: 1.098e-02, Validation Loss: 6.078e+00
# Epoch [305/500], Train Loss: 1.193e-02, Validation Loss: 6.543e+00
# Epoch [306/500], Train Loss: 1.177e-02, Validation Loss: 6.050e+00
# Epoch [307/500], Train Loss: 1.117e-02, Validation Loss: 5.746e+00
# Epoch [308/500], Train Loss: 1.089e-02, Validation Loss: 5.527e+00
# Epoch [309/500], Train Loss: 1.099e-02, Validation Loss: 5.405e+00
# Epoch [310/500], Train Loss: 1.101e-02, Validation Loss: 5.260e+00
# Epoch [311/500], Train Loss: 1.073e-02, Validation Loss: 5.200e+00
# Epoch [312/500], Train Loss: 1.083e-02, Validation Loss: 5.365e+00
# Epoch [313/500], Train Loss: 1.084e-02, Validation Loss: 5.390e+00
# Epoch [314/500], Train Loss: 1.115e-02, Validation Loss: 5.338e+00
# Epoch [315/500], Train Loss: 1.096e-02, Validation Loss: 5.256e+00
# Epoch [316/500], Train Loss: 1.093e-02, Validation Loss: 5.138e+00
# Epoch [317/500], Train Loss: 1.108e-02, Validation Loss: 5.182e+00
# Epoch [318/500], Train Loss: 1.070e-02, Validation Loss: 5.104e+00
# Epoch [319/500], Train Loss: 1.066e-02, Validation Loss: 5.151e+00
# Epoch [320/500], Train Loss: 1.124e-02, Validation Loss: 5.101e+00
# Epoch [321/500], Train Loss: 1.085e-02, Validation Loss: 5.052e+00
# Epoch [322/500], Train Loss: 1.089e-02, Validation Loss: 5.048e+00
# Epoch [323/500], Train Loss: 1.123e-02, Validation Loss: 5.063e+00
# Epoch [324/500], Train Loss: 1.110e-02, Validation Loss: 5.043e+00
# Epoch [325/500], Train Loss: 1.131e-02, Validation Loss: 5.033e+00
# Epoch [326/500], Train Loss: 1.064e-02, Validation Loss: 5.078e+00
# Epoch [327/500], Train Loss: 1.063e-02, Validation Loss: 5.151e+00
# Epoch [328/500], Train Loss: 1.078e-02, Validation Loss: 5.148e+00
# Epoch [329/500], Train Loss: 1.080e-02, Validation Loss: 5.499e+00
# Epoch [330/500], Train Loss: 1.187e-02, Validation Loss: 5.228e+00
# Epoch [331/500], Train Loss: 1.120e-02, Validation Loss: 5.521e+00
# Epoch [332/500], Train Loss: 1.083e-02, Validation Loss: 5.536e+00
# Epoch [333/500], Train Loss: 1.091e-02, Validation Loss: 5.233e+00
# Epoch [334/500], Train Loss: 1.153e-02, Validation Loss: 5.213e+00
# Epoch [335/500], Train Loss: 1.104e-02, Validation Loss: 5.193e+00
# Epoch [336/500], Train Loss: 1.076e-02, Validation Loss: 5.224e+00
# Epoch [337/500], Train Loss: 1.091e-02, Validation Loss: 5.244e+00
# Epoch [338/500], Train Loss: 1.179e-02, Validation Loss: 5.309e+00
# Epoch [339/500], Train Loss: 1.058e-02, Validation Loss: 5.154e+00
# Epoch [340/500], Train Loss: 1.055e-02, Validation Loss: 5.139e+00
# Epoch [341/500], Train Loss: 1.090e-02, Validation Loss: 4.975e+00
# Epoch [342/500], Train Loss: 1.078e-02, Validation Loss: 5.021e+00
# Epoch [343/500], Train Loss: 1.085e-02, Validation Loss: 4.989e+00
# Epoch [344/500], Train Loss: 1.117e-02, Validation Loss: 5.019e+00
# Epoch [345/500], Train Loss: 1.074e-02, Validation Loss: 4.944e+00
# Epoch [346/500], Train Loss: 1.105e-02, Validation Loss: 4.980e+00
# Epoch [347/500], Train Loss: 1.066e-02, Validation Loss: 4.948e+00
# Epoch [348/500], Train Loss: 1.111e-02, Validation Loss: 5.059e+00
# Epoch [349/500], Train Loss: 1.078e-02, Validation Loss: 4.930e+00
# Epoch [350/500], Train Loss: 1.073e-02, Validation Loss: 5.095e+00
# Epoch [351/500], Train Loss: 1.085e-02, Validation Loss: 4.997e+00
# Epoch [352/500], Train Loss: 1.062e-02, Validation Loss: 5.111e+00
# Epoch [353/500], Train Loss: 1.138e-02, Validation Loss: 4.979e+00
# Epoch [354/500], Train Loss: 1.063e-02, Validation Loss: 5.214e+00
# Epoch [355/500], Train Loss: 1.049e-02, Validation Loss: 5.067e+00
# Epoch [356/500], Train Loss: 1.049e-02, Validation Loss: 5.445e+00
# Epoch [357/500], Train Loss: 1.064e-02, Validation Loss: 5.181e+00
# Epoch [358/500], Train Loss: 1.084e-02, Validation Loss: 5.530e+00
# Epoch [359/500], Train Loss: 1.063e-02, Validation Loss: 5.763e+00
# Epoch [360/500], Train Loss: 1.088e-02, Validation Loss: 6.340e+00
# Epoch [361/500], Train Loss: 1.093e-02, Validation Loss: 5.492e+00
# Epoch [362/500], Train Loss: 1.080e-02, Validation Loss: 5.694e+00
# Epoch [363/500], Train Loss: 1.080e-02, Validation Loss: 5.357e+00
# Epoch [364/500], Train Loss: 1.074e-02, Validation Loss: 5.393e+00
# Epoch [365/500], Train Loss: 1.072e-02, Validation Loss: 5.680e+00
# Epoch [366/500], Train Loss: 1.167e-02, Validation Loss: 5.328e+00
# Epoch [367/500], Train Loss: 1.063e-02, Validation Loss: 5.183e+00
# Epoch [368/500], Train Loss: 1.083e-02, Validation Loss: 5.081e+00
# Epoch [369/500], Train Loss: 1.062e-02, Validation Loss: 4.982e+00
# Epoch [370/500], Train Loss: 1.075e-02, Validation Loss: 4.892e+00
# Epoch [371/500], Train Loss: 1.095e-02, Validation Loss: 4.880e+00
# Epoch [372/500], Train Loss: 1.052e-02, Validation Loss: 4.890e+00
# Epoch [373/500], Train Loss: 1.082e-02, Validation Loss: 4.922e+00
# Epoch [374/500], Train Loss: 1.096e-02, Validation Loss: 4.889e+00
# Epoch [375/500], Train Loss: 1.053e-02, Validation Loss: 4.941e+00
# Epoch [376/500], Train Loss: 1.061e-02, Validation Loss: 4.845e+00
# Epoch [377/500], Train Loss: 1.057e-02, Validation Loss: 4.827e+00
# Epoch [378/500], Train Loss: 1.046e-02, Validation Loss: 4.869e+00
# Epoch [379/500], Train Loss: 1.135e-02, Validation Loss: 4.832e+00
# Epoch [380/500], Train Loss: 1.069e-02, Validation Loss: 4.823e+00
# Epoch [381/500], Train Loss: 1.050e-02, Validation Loss: 5.055e+00
# Epoch [382/500], Train Loss: 1.061e-02, Validation Loss: 4.849e+00
# Epoch [383/500], Train Loss: 1.062e-02, Validation Loss: 5.114e+00
# Epoch [384/500], Train Loss: 1.042e-02, Validation Loss: 5.164e+00
# Epoch [385/500], Train Loss: 1.058e-02, Validation Loss: 5.019e+00
# Epoch [386/500], Train Loss: 1.135e-02, Validation Loss: 5.072e+00
# Epoch [387/500], Train Loss: 1.102e-02, Validation Loss: 5.229e+00
# Epoch [388/500], Train Loss: 1.116e-02, Validation Loss: 5.216e+00
# Epoch [389/500], Train Loss: 1.063e-02, Validation Loss: 5.242e+00
# Epoch [390/500], Train Loss: 1.051e-02, Validation Loss: 5.286e+00
# Epoch [391/500], Train Loss: 1.052e-02, Validation Loss: 5.141e+00
# Epoch [392/500], Train Loss: 1.060e-02, Validation Loss: 5.147e+00
# Epoch [393/500], Train Loss: 1.082e-02, Validation Loss: 4.996e+00
# Epoch [394/500], Train Loss: 1.061e-02, Validation Loss: 5.600e+00
# Epoch [395/500], Train Loss: 1.077e-02, Validation Loss: 5.055e+00
# Epoch [396/500], Train Loss: 1.065e-02, Validation Loss: 5.267e+00
# Epoch [397/500], Train Loss: 1.054e-02, Validation Loss: 4.948e+00
# Epoch [398/500], Train Loss: 1.065e-02, Validation Loss: 5.026e+00
# Epoch [399/500], Train Loss: 1.041e-02, Validation Loss: 4.854e+00
# Epoch [400/500], Train Loss: 1.128e-02, Validation Loss: 5.275e+00
# Epoch [401/500], Train Loss: 1.092e-02, Validation Loss: 4.984e+00
# Epoch [402/500], Train Loss: 1.051e-02, Validation Loss: 5.273e+00
# Epoch [403/500], Train Loss: 1.050e-02, Validation Loss: 5.107e+00
# Epoch [404/500], Train Loss: 1.162e-02, Validation Loss: 6.106e+00
# Epoch [405/500], Train Loss: 1.086e-02, Validation Loss: 5.197e+00
# Epoch [406/500], Train Loss: 1.089e-02, Validation Loss: 6.050e+00
# Epoch [407/500], Train Loss: 1.117e-02, Validation Loss: 5.112e+00
# Epoch [408/500], Train Loss: 1.076e-02, Validation Loss: 5.585e+00
# Epoch [409/500], Train Loss: 1.122e-02, Validation Loss: 4.973e+00
# Epoch [410/500], Train Loss: 1.068e-02, Validation Loss: 5.176e+00
# Epoch [411/500], Train Loss: 1.044e-02, Validation Loss: 4.826e+00
# Epoch [412/500], Train Loss: 1.072e-02, Validation Loss: 5.078e+00
# Epoch [413/500], Train Loss: 1.053e-02, Validation Loss: 4.849e+00
# Epoch [414/500], Train Loss: 1.048e-02, Validation Loss: 4.914e+00
# Epoch [415/500], Train Loss: 1.082e-02, Validation Loss: 4.821e+00
# Epoch [416/500], Train Loss: 1.048e-02, Validation Loss: 4.882e+00
# Epoch [417/500], Train Loss: 1.079e-02, Validation Loss: 4.899e+00
# Epoch [418/500], Train Loss: 1.077e-02, Validation Loss: 4.830e+00
# Epoch [419/500], Train Loss: 1.044e-02, Validation Loss: 4.850e+00
# Epoch [420/500], Train Loss: 1.051e-02, Validation Loss: 4.810e+00
# Epoch [421/500], Train Loss: 1.050e-02, Validation Loss: 4.765e+00
# Epoch [422/500], Train Loss: 1.048e-02, Validation Loss: 4.773e+00
# Epoch [423/500], Train Loss: 1.132e-02, Validation Loss: 4.802e+00
# Epoch [424/500], Train Loss: 1.060e-02, Validation Loss: 4.726e+00
# Epoch [425/500], Train Loss: 1.085e-02, Validation Loss: 4.833e+00
# Epoch [426/500], Train Loss: 1.128e-02, Validation Loss: 4.718e+00
# Epoch [427/500], Train Loss: 1.045e-02, Validation Loss: 4.913e+00
# Epoch [428/500], Train Loss: 1.052e-02, Validation Loss: 4.701e+00
# Epoch [429/500], Train Loss: 1.089e-02, Validation Loss: 5.360e+00
# Epoch [430/500], Train Loss: 1.135e-02, Validation Loss: 5.765e+00
# Epoch [431/500], Train Loss: 1.167e-02, Validation Loss: 5.890e+00
# Epoch [432/500], Train Loss: 1.178e-02, Validation Loss: 5.619e+00
# Epoch [433/500], Train Loss: 1.159e-02, Validation Loss: 5.481e+00
# Epoch [434/500], Train Loss: 1.163e-02, Validation Loss: 5.539e+00
# Epoch [435/500], Train Loss: 1.126e-02, Validation Loss: 5.244e+00
# Epoch [436/500], Train Loss: 1.110e-02, Validation Loss: 5.185e+00
# Epoch [437/500], Train Loss: 1.085e-02, Validation Loss: 5.061e+00
# Epoch [438/500], Train Loss: 1.082e-02, Validation Loss: 4.932e+00
# Epoch [439/500], Train Loss: 1.094e-02, Validation Loss: 5.045e+00
# Epoch [440/500], Train Loss: 1.078e-02, Validation Loss: 4.726e+00
# Epoch [441/500], Train Loss: 1.140e-02, Validation Loss: 4.630e+00
# Epoch [442/500], Train Loss: 1.097e-02, Validation Loss: 4.548e+00
# Epoch [443/500], Train Loss: 1.096e-02, Validation Loss: 4.518e+00
# Epoch [444/500], Train Loss: 1.121e-02, Validation Loss: 4.481e+00
# Epoch [445/500], Train Loss: 1.119e-02, Validation Loss: 4.458e+00
# Epoch [446/500], Train Loss: 1.093e-02, Validation Loss: 4.475e+00
# Epoch [447/500], Train Loss: 1.072e-02, Validation Loss: 4.515e+00
# Epoch [448/500], Train Loss: 1.077e-02, Validation Loss: 4.488e+00
# Epoch [449/500], Train Loss: 1.070e-02, Validation Loss: 4.437e+00
# Epoch [450/500], Train Loss: 1.068e-02, Validation Loss: 4.396e+00
# Epoch [451/500], Train Loss: 1.092e-02, Validation Loss: 4.377e+00
# Epoch [452/500], Train Loss: 1.079e-02, Validation Loss: 4.355e+00
# Epoch [453/500], Train Loss: 1.061e-02, Validation Loss: 4.330e+00
# Epoch [454/500], Train Loss: 1.071e-02, Validation Loss: 4.312e+00
# Epoch [455/500], Train Loss: 1.074e-02, Validation Loss: 4.293e+00
# Epoch [456/500], Train Loss: 1.051e-02, Validation Loss: 4.400e+00
# Epoch [457/500], Train Loss: 1.073e-02, Validation Loss: 4.647e+00
# Epoch [458/500], Train Loss: 1.115e-02, Validation Loss: 4.677e+00
# Epoch [459/500], Train Loss: 1.090e-02, Validation Loss: 4.702e+00
# Epoch [460/500], Train Loss: 1.102e-02, Validation Loss: 4.824e+00
# Epoch [461/500], Train Loss: 1.076e-02, Validation Loss: 4.611e+00
# Epoch [462/500], Train Loss: 1.076e-02, Validation Loss: 4.592e+00
# Epoch [463/500], Train Loss: 1.121e-02, Validation Loss: 4.440e+00
# Epoch [464/500], Train Loss: 1.125e-02, Validation Loss: 4.396e+00
# Epoch [465/500], Train Loss: 1.046e-02, Validation Loss: 4.320e+00
# Epoch [466/500], Train Loss: 1.058e-02, Validation Loss: 4.279e+00
# Epoch [467/500], Train Loss: 1.061e-02, Validation Loss: 4.261e+00
# Epoch [468/500], Train Loss: 1.062e-02, Validation Loss: 4.269e+00
# Epoch [469/500], Train Loss: 1.088e-02, Validation Loss: 4.256e+00
# Epoch [470/500], Train Loss: 1.125e-02, Validation Loss: 4.254e+00
# Epoch [471/500], Train Loss: 1.045e-02, Validation Loss: 4.262e+00
# Epoch [472/500], Train Loss: 1.233e-02, Validation Loss: 4.247e+00
# Epoch [473/500], Train Loss: 1.089e-02, Validation Loss: 4.280e+00
# Epoch [474/500], Train Loss: 1.042e-02, Validation Loss: 4.305e+00
# Epoch [475/500], Train Loss: 1.175e-02, Validation Loss: 4.350e+00
# Epoch [476/500], Train Loss: 1.059e-02, Validation Loss: 4.403e+00
# Epoch [477/500], Train Loss: 1.047e-02, Validation Loss: 4.592e+00
# Epoch [478/500], Train Loss: 1.053e-02, Validation Loss: 4.662e+00
# Epoch [479/500], Train Loss: 1.073e-02, Validation Loss: 4.468e+00
# Epoch [480/500], Train Loss: 1.058e-02, Validation Loss: 4.512e+00
# Epoch [481/500], Train Loss: 1.102e-02, Validation Loss: 4.378e+00
# Epoch [482/500], Train Loss: 1.073e-02, Validation Loss: 4.398e+00
# Epoch [483/500], Train Loss: 1.049e-02, Validation Loss: 4.337e+00
# Epoch [484/500], Train Loss: 1.055e-02, Validation Loss: 4.345e+00
# Epoch [485/500], Train Loss: 1.057e-02, Validation Loss: 4.361e+00
# Epoch [486/500], Train Loss: 1.048e-02, Validation Loss: 4.479e+00
# Epoch [487/500], Train Loss: 1.094e-02, Validation Loss: 5.528e+00
# Epoch [488/500], Train Loss: 1.111e-02, Validation Loss: 4.801e+00
# Epoch [489/500], Train Loss: 1.095e-02, Validation Loss: 4.603e+00
# Epoch [490/500], Train Loss: 1.089e-02, Validation Loss: 4.785e+00
# Epoch [491/500], Train Loss: 1.119e-02, Validation Loss: 4.493e+00
# Epoch [492/500], Train Loss: 1.071e-02, Validation Loss: 4.455e+00
# Epoch [493/500], Train Loss: 1.077e-02, Validation Loss: 4.364e+00
# Epoch [494/500], Train Loss: 1.080e-02, Validation Loss: 4.406e+00
# Epoch [495/500], Train Loss: 1.057e-02, Validation Loss: 4.286e+00
# Epoch [496/500], Train Loss: 1.041e-02, Validation Loss: 4.721e+00
# Epoch [497/500], Train Loss: 1.066e-02, Validation Loss: 4.707e+00
# Epoch [498/500], Train Loss: 1.072e-02, Validation Loss: 5.217e+00
# Epoch [499/500], Train Loss: 1.104e-02, Validation Loss: 4.911e+00
# Epoch [500/500], Train Loss: 1.082e-02, Validation Loss: 4.906e+00

# %%
torch.save(model, 'model.pth')
print('best epoch: ', best_epoch + 1)

plt.plot(train_loss, label="Train Loss")
plt.plot(validation_loss, label="Validation Loss")
plt.legend()
plt.yscale("log")
plt.title("Loss Curve")
plt.show()
# Out:
# best epoch:  472

# %%
#model = best_model     # least validation does not work well

# %%
# Evaluate the model on the training and test sets
running_test_loss = 0.0
for xx,yy,tt  in test_loader:
    xx = xx.to(device)
    yy = yy.to(device)
    tt = tt.to(device)
    with torch.no_grad():
        outputs = model(xx, tt*0.)    
        test_loss = criterion(outputs, yy)
    running_test_loss += test_loss.item()
    
# Calculate the MSE test sets
test_mse = running_test_loss/len(test_loader)
print(f"Test MSE: {test_mse:.4f}")

# Plot predictions for a few samples from the test set
sample = 0
for xx,yy,tt  in test_loader:
    sample = sample + 1
    xx = xx.to(device)
    yy = yy.to(device)
    tt = tt.to(device)
    with torch.no_grad():
        outputs = model(xx, tt*0.)    
    
    fire_location_pred = outputs[0,0,2,:,:]
    fire_location_pred = fire_location_pred.detach().cpu().numpy()
    fire_location_true = yy[0,0,2,:,:]
    fire_location_true = fire_location_true.detach().cpu().numpy()
    print("sample: ", sample)
    plt.imshow(fire_location_pred.T)
    plt.colorbar(orientation='horizontal')
    plt.title("Fire Location Prediction")
    plt.show()
    plt.imshow(fire_location_true.T)
    plt.colorbar(orientation='horizontal')
    plt.title("Fire Location True")
    plt.show()
    err = (fire_location_true.T - fire_location_pred.T)
    plt.imshow(err)
    plt.colorbar(orientation='horizontal')
    plt.title("Fire Location Error")
    plt.show()
        
    if sample >= 5:
        break

# # Prepare submission file
# y_preds = {test_df['id'][idx]: pred_test_grid[idx][5:25].flatten(order='C').astype(np.float32) for idx in range(len(test_df))}

# df = pd.DataFrame.from_dict(y_preds, orient='index')
# df['id'] = df.index
# df = df.reset_index(drop=True)
# cols = ['id'] + df.columns.tolist()[:-1]
# df = df[cols]

# df.to_csv('submission.csv', index=False)
# Out:
# Test MSE: 4.9064
# sample:  1

# %%
# Submission generation 
# 20 autoregression steps for 27 test samples
y_preds = {}
ids = []
for idx in range(len(test_df)):
    theta, ustar, xi_f, uin, alpha, id = load_dataX(idx, test_df, 'test')
    
    theta = torch.Tensor(theta).unsqueeze(1)
    ustar = torch.Tensor(ustar).unsqueeze(1)
    xi_f = torch.Tensor(xi_f).unsqueeze(1)
    
    uin_tensor = torch.zeros_like(xi_f) + uin
    alpha_tensor = torch.zeros_like(xi_f) + alpha
    
    TUXUA = torch.cat([theta,ustar,xi_f, uin_tensor, alpha_tensor], dim=1)
    TUXUA = TUXUA.unsqueeze(0)
    
    xx = TUXUA[:,-history:,...]
    xx = xx.to(device)
    
    fire_loc = []
    for i in range(20):
        with torch.no_grad():        
            output = model(xx, torch.zeros(1).to(device)) 
            Temp = torch.cat([output,xx[:,-1:,-2:,:,:]], dim=2) 
            xx = torch.cat([xx[:,1:,:,:,:], Temp], dim=1)
            fire_loc.append(output[0,:,2,:,:])
    
    fire_location20 = torch.cat(fire_loc, dim=0)
    fire_location20 = fire_location20.detach().cpu().numpy().flatten(order='C').astype(np.float32)
    
    y_preds[id]= fire_location20
    ids.append(id)

df = pd.DataFrame.from_dict(y_preds,orient='index')
df['id'] = ids
#df.info()

#move id to first column
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
#reset index
df = df.reset_index(drop=True)

#df.head()
df.info()
df.to_csv('submission.csv',index=False)
print('Generated Submission file' )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 72321 entries, id to 72319
# dtypes: float32(72320), int64(1)
# memory usage: 7.4 MB
# Generated Submission file
